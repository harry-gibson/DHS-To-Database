# %% [markdown]
# ## Identify updated / new DHS surveys
#
# Compare what's available on the website to what we have in the database already.
#
# Any missing may be new, or we may not have access to them, or we may simply have chosen not to use them.

# %%
import pandas as pd
import pandas.io.sql as psql
#import psycopg2 as pg
from sqlalchemy import create_engine
import sqlalchemy as sa
import os
import glob

# %%
with open('config/pg_conn.txt') as conn_details:
    conn_str_psyco = conn_details.readline()
    conn_str_sqlalchemy = conn_details.readline()

# %%
engine = create_engine(conn_str_sqlalchemy)

# %% [markdown]
# We maintain a CSV of known issues to explain discrepancies between the listed survey availability and our actual holdings

# %%
known_issues_all = pd.read_csv('~/notebooks/DHS-DataExtraction/DHS_Preprocess_And_Ingestion/01_Check_Survey_Updates/missing_and_unavailable.csv')
known_issues_all.head()
# Out:
#    surveynum       country  year issue            data issue      gps issue  \
# 0         23      botswana  1988   NaN       restricted data  not collected
# 1         73       eritrea  1995   NaN       restricted data  not collected
# 2        103         yemen  1997   NaN       restricted data  not collected
# 3        179  turkmenistan  2000   NaN  not in public domain  not collected
# 4        160    mauritania  2000   NaN       restricted data  not collected
#
#   change expected last manual check
# 0              no        04/02/2019
# 1              no        04/02/2019
# 2              no        04/02/2019
# 3              no        04/02/2019
# 4              no        04/02/2019

# %% [markdown]
# ### Available surveys
#
# Query the DHS API for available surveys (may include ones our account does not have download access to)

# %%
# Note: presently this returns all surveys. In the past it has been paginated 
# so if that was to occur again we'd have to loop
surveys = pd.read_csv("http://api.dhsprogram.com/rest/dhs/surveys?f=csv",
                      usecols=['SurveyId', 'SurveyNum', 'ReleaseDate', 'SurveyCharacteristicIds', 'CountryName', 'RegionName'])

# %%
surveys.head()
# Out:
#     SurveyId  CountryName  SurveyNum                     RegionName  \
# 0  AF2015DHS  Afghanistan        471         South & Southeast Asia
# 1  AL2008DHS      Albania        327  North Africa/West Asia/Europe
# 2  AL2017DHS      Albania        525  North Africa/West Asia/Europe
# 3  AO2006MIS       Angola        282             Sub-Saharan Africa
# 4  AO2011MIS       Angola        395             Sub-Saharan Africa
#
#   ReleaseDate                            SurveyCharacteristicIds
# 0  2017-02-15  92, 39, 6, 1, 101, 79, 31, 14, 57, 8, 34, 17, ...
# 1  2010-03-15  33, 10, 43, 41, 31, 22, 26, 24, 21, 59, 11, 34...
# 2  2019-01-11  70, 93, 33, 41, 10, 43, 11, 34, 5, 60, 67, 31,...
# 3  2008-02-27         8, 41, 57, 36, 68, 63, 61, 26, 101, 79, 89
# 4  2012-01-24                 101, 79, 90, 41, 26, 57, 8, 17, 89

# %% [markdown]
# ### Updated surveys
#
# Query the DHS API for surveys updated since 2015 (may include ones our account does not have download access to)

# %%
recent_updates = pd.read_csv("http://api.dhsprogram.com/rest/dhs/dataupdates?lastUpdate=20150901&f=csv",
                            usecols=['SurveyId', 'SurveyYear', 'DHS_CountryCode', 'CountryName', 'UpdateDate'])

# %%
recent_updates.head()
# Out:
#     SurveyId  SurveyYear DHS_CountryCode CountryName             UpdateDate
# 0  TD2014DHS      2014.0              TD        Chad  2016-07-15 19:17:14.0
# 1  ZW2010DHS      2010.0              ZW    Zimbabwe  2016-12-07 20:54:25.0
# 2  GH2016MIS      2016.0              GH       Ghana  2017-07-27 17:52:17.0
# 3  ET2016DHS      2016.0              ET    Ethiopia  2017-08-16 21:17:18.0
# 4  AM2016DHS      2016.0              AM     Armenia  2017-08-30 17:46:51.0

# %% [markdown]
# The recent updates API endpoint doesn't return all details we need, so merge with the data from the main surveys endpoint

# %%
potential_recent_updates = recent_updates.merge(surveys, how='inner', on='SurveyId')
potential_recent_updates
# Out:
#      SurveyId  SurveyYear DHS_CountryCode     CountryName_x  \
# 0   TD2014DHS      2014.0              TD              Chad
# 1   ZW2010DHS      2010.0              ZW          Zimbabwe
# 2   GH2016MIS      2016.0              GH             Ghana
# 3   ET2016DHS      2016.0              ET          Ethiopia
# 4   AM2016DHS      2016.0              AM           Armenia
# 5   AM2016DHS      2016.0              AM           Armenia
# 6   SN2015DHS      2015.0              SN           Senegal
# 7   SN2016DHS      2016.0              SN           Senegal
# 8   SL2016MIS      2016.0              SL      Sierra Leone
# 9   NP2016DHS      2016.0              NP             Nepal
# 10  MZ2015AIS      2015.0              MZ        Mozambique
# 11  UG2016DHS      2016.0              UG            Uganda
# 12  BU2016DHS      2016.0              BU           Burundi
# 13  TL2016DHS      2016.0              TL       Timor-Leste
# 14  MW2017MIS      2017.0              MW            Malawi
# 15  TG2017MIS      2017.0              TG              Togo
# 16  HT2016DHS      2016.0              HT             Haiti
# 17  RW2017MIS      2017.0              RW            Rwanda
# 18  SN2017DHS      2017.0              SN           Senegal
# 19  SN2017DHS      2017.0              SN           Senegal
# 20  PH2017DHS      2017.0              PH       Philippines
# 21  TZ2017MIS      2017.0              TZ          Tanzania
# 22  AL2017DHS      2017.0              AL           Albania
# 23  ZA2016DHS      2016.0              ZA      South Africa
# 24  PK2017DHS      2017.0              PK          Pakistan
# 25  MV2016DHS      2016.0              MV          Maldives
# 26  JO2017DHS      2017.0              JO            Jordan
# 27  BJ2017DHS      2017.0              BJ             Benin
# 28  TR2008DHS      2008.0              TR            Turkey
# 29  TR2013DHS      2013.0              TR            Turkey
# 30  BF2017MIS      2017.0              BF      Burkina Faso
# 31  MZ2018MIS      2018.0              MZ        Mozambique
# 32  ML2018DHS      2018.0              ML              Mali
# 33  GN2018DHS      2018.0              GN            Guinea
# 34  PG2017DHS      2017.0              PG  Papua New Guinea
# 35  ZM2018DHS      2018.0              ZM            Zambia
# 36  UG2018MIS      2018.0              UG            Uganda
# 37  CM2018DHS      2018.0              CM          Cameroon
# 38  SN2018DHS      2018.0              SN           Senegal
# 39  SN2018DHS      2018.0              SN           Senegal
# 40  GH2019MIS      2019.0              GH             Ghana
# 41  SL2019DHS      2019.0              SL      Sierra Leone
# 42  BD2017DHS      2017.0              BD        Bangladesh
#
#                UpdateDate     CountryName_y  SurveyNum  \
# 0   2016-07-15 19:17:14.0              Chad        465
# 1   2016-12-07 20:54:25.0          Zimbabwe        367
# 2   2017-07-27 17:52:17.0             Ghana        516
# 3   2017-08-16 21:17:18.0          Ethiopia        478
# 4   2017-08-30 17:46:51.0           Armenia        492
# 5   2017-10-05 21:50:48.0           Armenia        492
# 6   2017-10-05 21:50:48.0           Senegal        489
# 7   2017-10-05 21:50:48.0           Senegal        524
# 8   2017-10-05 21:50:48.0      Sierra Leone        515
# 9   2017-11-13 15:29:15.0             Nepal        472
# 10  2018-02-26 04:32:38.0        Mozambique        467
# 11  2018-03-12 03:12:13.0            Uganda        504
# 12  2018-04-07 00:41:44.0           Burundi        463
# 13  2018-04-11 21:15:54.0       Timor-Leste        514
# 14  2018-04-25 17:31:14.0            Malawi        512
# 15  2018-08-08 15:31:54.0              Togo        497
# 16  2018-08-21 17:39:29.0             Haiti        503
# 17  2018-09-10 20:38:33.0            Rwanda        540
# 18  2018-09-27 17:32:30.0           Senegal        534
# 19  2018-09-27 17:33:30.0           Senegal        534
# 20  2018-10-03 20:22:23.0       Philippines        510
# 21  2018-10-22 20:34:21.0          Tanzania        529
# 22  2019-01-11 23:07:49.0           Albania        525
# 23  2019-01-30 18:59:38.0      South Africa        390
# 24  2019-02-25 23:42:49.0          Pakistan        523
# 25  2019-03-01 16:08:45.0          Maldives        494
# 26  2019-03-26 16:01:30.0            Jordan        500
# 27  2019-04-02 15:29:46.0             Benin        491
# 28  2019-06-30 21:56:54.0            Turkey        547
# 29  2019-06-30 21:56:54.0            Turkey        486
# 30  2019-07-11 15:10:31.0      Burkina Faso        526
# 31  2019-07-21 22:13:23.0        Mozambique        527
# 32  2019-09-19 14:31:56.0              Mali        517
# 33  2019-10-31 02:27:13.0            Guinea        539
# 34  2019-11-25 15:05:35.0  Papua New Guinea        499
# 35  2020-02-18 16:59:21.0            Zambia        542
# 36  2020-04-23 12:50:28.0            Uganda        549
# 37  2020-06-10 14:40:05.0          Cameroon        511
# 38  2020-06-17 16:08:04.0           Senegal        580
# 39  2020-06-17 16:31:16.0           Senegal        580
# 40  2020-07-28 13:00:49.0             Ghana        557
# 41  2020-12-11 16:01:50.0      Sierra Leone        545
# 42  2020-12-14 14:38:12.0        Bangladesh        536
#
#                        RegionName ReleaseDate  \
# 0              Sub-Saharan Africa  2016-07-11
# 1              Sub-Saharan Africa  2012-04-05
# 2              Sub-Saharan Africa  2017-07-27
# 3              Sub-Saharan Africa  2017-08-15
# 4   North Africa/West Asia/Europe  2017-08-30
# 5   North Africa/West Asia/Europe  2017-08-30
# 6              Sub-Saharan Africa  2016-11-04
# 7              Sub-Saharan Africa  2017-09-06
# 8              Sub-Saharan Africa  2017-09-21
# 9          South & Southeast Asia  2017-11-13
# 10             Sub-Saharan Africa  2018-02-26
# 11             Sub-Saharan Africa  2018-03-12
# 12             Sub-Saharan Africa  2018-04-05
# 13         South & Southeast Asia  2018-04-10
# 14             Sub-Saharan Africa  2018-04-25
# 15             Sub-Saharan Africa  2018-08-08
# 16      Latin America & Caribbean  2018-08-21
# 17             Sub-Saharan Africa  2018-09-07
# 18             Sub-Saharan Africa  2018-09-28
# 19             Sub-Saharan Africa  2018-09-28
# 20         South & Southeast Asia  2018-10-03
# 21             Sub-Saharan Africa  2018-10-22
# 22  North Africa/West Asia/Europe  2019-01-11
# 23             Sub-Saharan Africa  2019-01-30
# 24         South & Southeast Asia  2019-02-25
# 25         South & Southeast Asia  2019-02-25
# 26  North Africa/West Asia/Europe  2019-03-26
# 27             Sub-Saharan Africa  2019-04-02
# 28  North Africa/West Asia/Europe  2018-07-30
# 29  North Africa/West Asia/Europe  2018-07-30
# 30             Sub-Saharan Africa  2019-07-08
# 31             Sub-Saharan Africa  2019-07-19
# 32             Sub-Saharan Africa  2019-09-19
# 33             Sub-Saharan Africa  2019-10-30
# 34                        Oceania  2019-11-25
# 35             Sub-Saharan Africa  2020-02-18
# 36             Sub-Saharan Africa  2020-04-23
# 37             Sub-Saharan Africa  2020-06-10
# 38             Sub-Saharan Africa  2020-06-17
# 39             Sub-Saharan Africa  2020-06-17
# 40             Sub-Saharan Africa  2020-07-28
# 41             Sub-Saharan Africa  2020-12-11
# 42         South & Southeast Asia  2020-12-14
#
#                               SurveyCharacteristicIds
# 0   10, 33, 67, 32, 39, 34, 5, 6, 4, 1, 101, 104, ...
# 1   33, 17, 3, 79, 69, 24, 21, 23, 41, 10, 31, 22,...
# 2                              89, 92, 41, 70, 15, 57
# 3   91, 33, 15, 41, 10, 31, 22, 39, 26, 69, 24, 21...
# 4   16, 33, 31, 22, 26, 38, 69, 24, 21, 17, 87, 94...
# 5   16, 33, 31, 22, 26, 38, 69, 24, 21, 17, 87, 94...
# 6   90, 79, 34, 14, 4, 31, 32, 69, 15, 26, 57, 41,...
# 7   80, 26, 69, 14, 11, 34, 4, 15, 70, 22, 57, 79,...
# 8                      41, 90, 89, 79, 70, 26, 57, 92
# 9   6, 31, 14, 20, 17, 34, 36, 13, 9, 60, 3, 22, 3...
# 10  24, 81, 83, 91, 41, 47, 11, 51, 6, 92, 101, 89...
# 11  70, 24, 21, 11, 6, 4, 1, 10, 52, 31, 22, 67, 7...
# 12  26, 45, 80, 86, 91, 94, 70, 67, 5, 1, 33, 32, ...
# 13  33, 68, 79, 63, 80, 32, 24, 21, 14, 59, 20, 34...
# 14                                 41, 70, 92, 90, 89
# 15                                     70, 41, 90, 89
# 16  85, 24, 21, 91, 16, 41, 10, 43, 70, 67, 11, 6,...
# 17                                             89, 90
# 18  10, 22, 23, 57, 15, 41, 31, 70, 79, 80, 26, 69...
# 19  10, 22, 23, 57, 15, 41, 31, 70, 79, 80, 26, 69...
# 20  24, 69, 33, 38, 86, 30, 60, 21, 92, 87, 70, 6, 94
# 21                                     70, 26, 92, 89
# 22  70, 93, 33, 41, 10, 43, 11, 34, 5, 60, 67, 31,...
# 23  26, 91, 22, 79, 16, 23, 11, 41, 10, 43, 68, 67...
# 24  30, 16, 10, 78, 11, 6, 31, 85, 92, 26, 60, 2, ...
# 25   86, 11, 22, 70, 32, 38, 6, 4, 80, 41, 10, 94, 87
# 26      22, 11, 41, 10, 70, 67, 80, 38, 21, 6, 87, 16
# 27  6, 1, 67, 80, 90, 89, 86, 5, 11, 15, 41, 10, 4...
# 28                          16, 10, 31, 69, 14, 34, 3
# 29     10, 22, 3, 101, 69, 16, 31, 32, 38, 20, 34, 60
# 30                                41, 90, 89, 101, 92
# 31                                         41, 70, 89
# 32            22, 85, 39, 11, 6, 4, 1, 41, 10, 70, 89
# 33  70, 39, 26, 38, 24, 21, 23, 11, 4, 41, 10, 67,...
# 34  10, 78, 11, 6, 1, 74, 31, 22, 79, 69, 24, 21, ...
# 35  41, 10, 39, 23, 14, 6, 1, 59, 92, 26, 100, 17,...
# 36                 41, 90, 92, 70, 89, 79, 26, 57, 17
# 37  23, 16, 100, 70, 89, 11, 26, 68, 91, 104, 33, ...
# 38  31, 17, 3, 80, 26, 11, 10, 14, 6, 4, 32, 69, 8...
# 39  31, 17, 3, 80, 26, 11, 10, 14, 6, 4, 32, 69, 8...
# 40                 90, 17, 26, 70, 89, 92, 41, 79, 69
# 41       11, 41, 23, 70, 104, 1, 6, 4, 10, 89, 99, 26
# 42  38, 22, 70, 92, 31, 10, 43, 46, 9, 2, 41, 68, ...

# %% [markdown]
# ### Our surveys
#
# Define a survey as being in our database if it has an entry in any of the RECH1, REC01, MREC01 tables

# %%
our_surveys = pd.read_sql('''
    SELECT DISTINCT (surveyid) FROM dhs_data_tables."RECH1" 
    UNION 
    SELECT DISTINCT (surveyid) FROM dhs_data_tables."REC01"
    UNION 
    SELECT DISTINCT (surveyid) FROM dhs_data_tables."MREC01"''',
                         con=engine)

# %%
our_surveys.head()
# Out:
#   surveyid
# 0      354
# 1      497
# 2       13
# 3      383
# 4       93

# %% [markdown]
# ### Missing surveys
#
# List of all surveys that the API advertised but aren't in our DB for whatever reason

# %%
surveys_we_dont_have = surveys[~surveys['SurveyNum'].isin(our_surveys['surveyid'])]

# %%
surveys_we_dont_have
# Out:
#       SurveyId       CountryName  SurveyNum                     RegionName  \
# 18   BD2017DHS        Bangladesh        536         South & Southeast Asia
# 29   BT1988DHS          Botswana         23             Sub-Saharan Africa
# 90   ER1995DHS           Eritrea         73             Sub-Saharan Africa
# 91   ER2002DHS           Eritrea        170             Sub-Saharan Africa
# 107  GH2019MIS             Ghana        557             Sub-Saharan Africa
# 187  MR2000DHS        Mauritania        160             Sub-Saharan Africa
# 226  PG2017DHS  Papua New Guinea        499                        Oceania
# 265  SN2018DHS           Senegal        580             Sub-Saharan Africa
# 269  SL2019DHS      Sierra Leone        545             Sub-Saharan Africa
# 298  TR2008DHS            Turkey        547  North Africa/West Asia/Europe
# 299  TR2013DHS            Turkey        486  North Africa/West Asia/Europe
# 300  TM2000DHS      Turkmenistan        179                   Central Asia
# 304  UG2004AIS            Uganda        224             Sub-Saharan Africa
# 318  YE1997DHS             Yemen        103  North Africa/West Asia/Europe
#
#     ReleaseDate                            SurveyCharacteristicIds
# 18   2020-12-14  38, 22, 70, 92, 31, 10, 43, 46, 9, 2, 41, 68, ...
# 29   1989-08-01                             79, 3, 21, 20, 17, 101
# 90   1997-03-01                1, 2, 4, 10, 11, 21, 24, 79, 101, 3
# 91   2003-05-01  4, 13, 57, 17, 10, 14, 79, 101, 5, 3, 60, 20, ...
# 107  2020-07-28                 90, 17, 26, 70, 89, 92, 41, 79, 69
# 187  2001-12-01  1, 2, 4, 11, 21, 24, 57, 14, 32, 79, 101, 10, ...
# 226  2019-11-25  10, 78, 11, 6, 1, 74, 31, 22, 79, 69, 24, 21, ...
# 265  2020-06-17  31, 17, 3, 80, 26, 11, 10, 14, 6, 4, 32, 69, 8...
# 269  2020-12-11       11, 41, 23, 70, 104, 1, 6, 4, 10, 89, 99, 26
# 298  2018-07-30                          16, 10, 31, 69, 14, 34, 3
# 299  2018-07-30     10, 22, 3, 101, 69, 16, 31, 32, 38, 20, 34, 60
# 300  2001-09-01  16, 22, 36, 41, 43, 21, 15, 10, 14, 20, 13, 10...
# 304  2006-03-01  24, 31, 53, 54, 59, 36, 47, 40, 21, 11, 101, 1...
# 318  1998-11-01       1, 4, 14, 20, 17, 101, 34, 61, 3, 10, 79, 94

# %% [markdown]
# List of surveys for which we've previously noted that we'll never get the data due to known issues

# %%
known_survey_issues = known_issues_all.loc[
    (known_issues_all['change expected']=='no') & (known_issues_all['data issue'] != 'no issue')
]
known_survey_issues
# Out:
#    surveynum       country  year issue              data issue  \
# 0         23      botswana  1988   NaN         restricted data
# 1         73       eritrea  1995   NaN         restricted data
# 2        103         yemen  1997   NaN         restricted data
# 3        179  turkmenistan  2000   NaN    not in public domain
# 4        160    mauritania  2000   NaN         restricted data
# 5        170       eritrea  2002   NaN         restricted data
# 6        224        uganda  2004   NaN         restricted data
# 7        525       albania  2017   NaN  we don't care about it
#
#                      gps issue change expected last manual check
# 0                not collected              no        04/02/2019
# 1                not collected              no        04/02/2019
# 2                not collected              no        04/02/2019
# 3                not collected              no        04/02/2019
# 4                not collected              no        04/02/2019
# 5              restricted data              no        04/02/2019
# 6                not collected              no        04/02/2019
# 7  we are not approved for gps              no        04/02/2019

# %% [markdown]
# ### Listing of surveys that we don't have and might want to get

# %%
_ = ~surveys_we_dont_have['SurveyNum'].isin(known_survey_issues['surveynum'])
survey_data_to_look_for = surveys_we_dont_have[_]
survey_data_to_look_for
# Out:
#       SurveyId       CountryName  SurveyNum                     RegionName  \
# 18   BD2017DHS        Bangladesh        536         South & Southeast Asia
# 107  GH2019MIS             Ghana        557             Sub-Saharan Africa
# 226  PG2017DHS  Papua New Guinea        499                        Oceania
# 265  SN2018DHS           Senegal        580             Sub-Saharan Africa
# 269  SL2019DHS      Sierra Leone        545             Sub-Saharan Africa
# 298  TR2008DHS            Turkey        547  North Africa/West Asia/Europe
# 299  TR2013DHS            Turkey        486  North Africa/West Asia/Europe
#
#     ReleaseDate                            SurveyCharacteristicIds
# 18   2020-12-14  38, 22, 70, 92, 31, 10, 43, 46, 9, 2, 41, 68, ...
# 107  2020-07-28                 90, 17, 26, 70, 89, 92, 41, 79, 69
# 226  2019-11-25  10, 78, 11, 6, 1, 74, 31, 22, 79, 69, 24, 21, ...
# 265  2020-06-17  31, 17, 3, 80, 26, 11, 10, 14, 6, 4, 32, 69, 8...
# 269  2020-12-11       11, 41, 23, 70, 104, 1, 6, 4, 10, 89, 99, 26
# 298  2018-07-30                          16, 10, 31, 69, 14, 34, 3
# 299  2018-07-30     10, 22, 3, 101, 69, 16, 31, 32, 38, 20, 34, 60

# %% [markdown]
# ## GPS data
#
# Listing of all the surveys we have GPS data for

# %%
our_gps_data = pd.read_sql('''
    SELECT DISTINCT (surveyid) FROM dhs_data_locations.dhs_cluster_locs''',
                         con=engine)

# %%
our_gps_data.head()
# Out:
#    surveyid
# 0       145
# 1       435
# 2        58
# 3       228
# 4       384

# %% [markdown]
# Listing of all the surveys for which GPS data are available, according to the API

# %%
available_gps_data = surveys[surveys['SurveyCharacteristicIds'].str.contains('26')]['SurveyNum']
available_gps_data
# Out:
# 0      471
# 1      327
# 3      282
# 4      395
# 5      477
#       ...
# 325    542
# 328    184
# 329    260
# 330    367
# 331    475
# Name: SurveyNum, Length: 201, dtype: int64

# %% [markdown]
# Listing of all the GPS data which are advertised as available but we don't have

# %%
gps_data_we_dont_have = available_gps_data[~available_gps_data.isin(our_gps_data['surveyid'])]
gps_data_we_dont_have
# Out:
# 0      471
# 7      262
# 47     101
# 91     170
# 107    557
# 147    115
# 165    207
# 213    277
# 214    407
# 224    419
# 235    426
# 236    433
# 237    434
# 245    165
# 264    534
# 265    580
# 269    545
# 277     82
# 319    358
# 322    206
# Name: SurveyNum, dtype: int64

# %% [markdown]
# Listing of surveys for which we've previously noted that we'll never get the GPS data due to known issues

# %%
known_gps_issues = known_issues_all.loc[
    (known_issues_all['change expected']=='no') & (known_issues_all['gps issue'] != 'no issue')
]['surveynum']
known_gps_issues
# Out:
# 0      23
# 1      73
# 2     103
# 3     179
# 4     160
# 5     170
# 6     224
# 7     525
# 8     101
# 9     115
# 10    165
# 11    206
# 12    207
# 13    262
# 14    277
# 15    358
# 16    407
# 17    419
# 18    426
# 19    433
# 20    434
# 21    471
# 23     82
# Name: surveynum, dtype: int64

# %% [markdown]
# ### Listing of GPS data that we don't have and might want to get

# %%
gps_data_to_look_for = gps_data_we_dont_have[~gps_data_we_dont_have.isin(known_gps_issues)]
gps_data_to_look_for
# Out:
# 107    557
# 264    534
# 265    580
# 269    545
# Name: SurveyNum, dtype: int64

# %%
surveys[surveys['SurveyNum'].isin(gps_data_to_look_for)]
# Out:
#       SurveyId   CountryName  SurveyNum          RegionName ReleaseDate  \
# 107  GH2019MIS         Ghana        557  Sub-Saharan Africa  2020-07-28
# 264  SN2017DHS       Senegal        534  Sub-Saharan Africa  2018-09-28
# 265  SN2018DHS       Senegal        580  Sub-Saharan Africa  2020-06-17
# 269  SL2019DHS  Sierra Leone        545  Sub-Saharan Africa  2020-12-11
#
#                                SurveyCharacteristicIds
# 107                 90, 17, 26, 70, 89, 92, 41, 79, 69
# 264  10, 22, 23, 57, 15, 41, 31, 70, 79, 80, 26, 69...
# 265  31, 17, 3, 80, 26, 11, 10, 14, 6, 4, 32, 69, 8...
# 269       11, 41, 23, 70, 104, 1, 6, 4, 10, 89, 99, 26

# %% [markdown]
# ## Next steps:
#
# Code is no longer provided to automatically download / scrape the data from the DHS website. They took steps to prevent this so we aren't going to try and circumvent it.
#
# Instead, you should use the batch download tool they do provide in conjunction with a browser bulk download utility to get the necessary files.
#
# For each survey, you should download the "Individual Recode - Hierarchical ASCII data (.dat)" and the "Men's Recode - Hierarchical ASCII data (.dat)" files, as well as the Geographic Data where available.
#
# For any that turn out not to be available, suggesting a mismatch between the API and reality, update the CSV files if appropriate to note this.
#
# Once downloaded, unzip and rename the files using notebook 02.
