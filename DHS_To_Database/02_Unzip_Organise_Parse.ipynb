# %%
import lib02_Unzip_And_Organise_Downloads

# %% [markdown]
# Either provide:
#
# a) The path to a folder in which you have manually downloaded some survey data zip files. In this case, the files need to have been manually renamed to prepend the numeric survey id followed by a dot; for example `SLIR7A.ZIP` needs to have been renamed to `545.SLIR7A.ZIP`
#
# or
#
# b) the path to a download URLs text file from the DHS batch download utility (see [here](https://dhsprogram.com/data/Access-Instructions.cfm#multiplesurveys) for info on this). The files it specified should already have been downloaded using a batch download extension as described in the video, into the same folder as the provided URLs text file.
#
#
# You also need to provide a path to a staging folder. If they do not already exist, subdirectories named `downloaded`, `parsed_specs`, and `tables` will be created.
#
# The zip files will be extracted to subfolders of `downloaded` named according to the numeric survey id.
#
# The DCF specifications will be extracted to the `parsed_specs` folder, a total of 3 CSV files per survey
#
# The data tables will be extracted to the `tables` folder, one CSV file per table per survey.
#
# The code will check whether a given file has already been unzipped and parsed so it is safe, and recommended, to run with the same staging folder every time that can contain an archive of all previous extractions.
#
# ## option a: parsing manually downloaded files

# %%
manual_download_folder = '/mnt/d/InformalCities/DHS_Updates/tmp/'

lib02_Unzip_And_Organise_Downloads.run(downloads_file_or_folder=manual_download_folder,
                                       staging_folder='/mnt/d/InformalCities/DHS_Updates/staging/',
                                       parse_dcfs=True,
                                       parse_data=True
                                      )
# Out:
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/499/499.PGIR71.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/499/499.PGMR71.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/536/536.BDIR7R.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/545/545.SLIR7A.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/545/545.SLMR7A.DCF is already done, skipping
# 499.PGIR71 already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/499/499.PGMR71.DAT
# 536.BDIR7R already parsed to datafiles, skipping
# 545.SLIR7A already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/545/545.SLMR7A.DAT

# %% [markdown]
# ## option b: parsing batch downloaded files

# %%
download_urls_file = '/mnt/d/InformalCities/DHS_Updates/dhs_hierarchical/download_urls.txt'
lib02_Unzip_And_Organise_Downloads.run(downloads_file_or_folder=download_urls_file,
                                      staging_folder='/mnt/d/InformalCities/DHS_Updates/staging/',
                                      parse_dcfs=True,
                                      parse_data=True)
# Out:
# BDIR41.ZIP has not been downloaded, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/471/471.AFIR70.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/471/471.AFMR70.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/282/282.AOIR51.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/395/395.AOIR62.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/477/477.AOIR71.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/477/477.AOMR71.DCF is already done, skipping
# Parsed 21931 lines into 1392 items
# Parsed 21931 lines into 1392 items
# Parsed 21931 lines into 1392 items
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/59/59.BDIR31.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/89/89.BDIR3A.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/236/236.BDIR4J.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/287/287.BDIR51.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/349/349.BDIR61.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/461/461.BDIR72.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/59/59.BDMR31.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/89/89.BDMR3A.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/135/135.BDMR41.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/236/236.BDMR4J.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/287/287.BDMR51.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/349/349.BDMR61.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/42/42.BFIR21.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/116/116.BFIR31.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/230/230.bfir43.dcf is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/329/329.BFIR62.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/481/481.BFIR71.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/526/526.BFIR7A.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/42/42.BFMR21.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/116/116.BFMR31.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/230/230.BFMR41.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/329/329.BFMR62.DCF is already done, skipping
# Parsed 21930 lines into 1392 items
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/87/87.BJIR31.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/211/211.BJIR41.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/289/289.BJIR51.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/420/420.BJIR61.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/491/491.BJIR71.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/87/87.BJMR31.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/211/211.BJMR41.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/289/289.BJMR51.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/420/420.BJMR61.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/491/491.BJMR71.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/28/28.BOIR01.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/65/65.BOIR31.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/98/98.BOIR3B.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/238/238.BOIR41.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/319/319.BOIR51.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/98/98.BOMR3B.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/238/238.BOMR41.dcf is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/319/319.BOMR51.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/2/2.BRIR01.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/40/40.BRIR21.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/85/85.BRIR31.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/85/85.BRMR31.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/16/16.BUIR02.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/346/346.BUIR61.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/446/446.BUIR6A.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/463/463.BUIR71.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/346/346.BUMR61.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/463/463.BUMR71.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded/239/239.CDIR51.DCF is already done, skipping
# /mnt/d/InformalCities/DHS_Updates/staging/downloaded
parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/77/77.MLMR31.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/159/159.mlmr41.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/276/276.MLMR53.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/405/405.MLMR6A.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/517/517.MLMR7A.DAT
# 454.MMIR71 already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/454/454.MMMR71.DAT
# 156.MNIR42 already parsed to datafiles, skipping
# 156.MPIR42 already parsed to datafiles, skipping
# 52.MWIR22 already parsed to datafiles, skipping
# 158.MWIR41 already parsed to datafiles, skipping
# 251.MWIR4E already parsed to datafiles, skipping
# 333.MWIR61 already parsed to datafiles, skipping
# 432.MWIR6A already parsed to datafiles, skipping
# 473.MWIR71 already parsed to datafiles, skipping
# 483.MWIR7A already parsed to datafiles, skipping
# 512.MWIR7I already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/52/52.MWMR21.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/158/158.MWMR41.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/251/251.MWMR4E.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/333/333.MWMR61.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/483/483.MWMR7A.DAT
# 11.MXIR01 already parsed to datafiles, skipping
# 105.MZIR31 already parsed to datafiles, skipping
# 174.MZIR41 already parsed to datafiles, skipping
# 156.MZIR42 already parsed to datafiles, skipping
# 322.MZIR51 already parsed to datafiles, skipping
# 362.MZIR62 already parsed to datafiles, skipping
# 467.MZIR71 already parsed to datafiles, skipping
# 527.MZIR7A already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/105/105.MZMR31.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/174/174.mzmr41.dat
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/362/362.MZMR62.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/467/467.MZMR71.DAT
# No rows were found for record type M31 in file 467.MZMR71 despite DCF specification
# 156.NAIR42 already parsed to datafiles, skipping
# 112.NCIR31 already parsed to datafiles, skipping
# 204.NCIR41 already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/112/112.NCMR31.DAT
# 32.NGIR21 already parsed to datafiles, skipping
# 223.NGIR4B already parsed to datafiles, skipping
# 302.NGIR53 already parsed to datafiles, skipping
# 392.NGIR61 already parsed to datafiles, skipping
# 438.NGIR6A already parsed to datafiles, skipping
# 474.NGIR71 already parsed to datafiles, skipping
# 528.NGIR7A already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/223/223.ngmr4a.dat
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/302/302.NGMR52.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/438/438.NGMR6A.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/528/528.NGMR7A.DAT
# 53.NIIR22 already parsed to datafiles, skipping
# 99.NIIR31 already parsed to datafiles, skipping
# 277.NIIR51 already parsed to datafiles, skipping
# 407.NIIR61 already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/53/53.NIMR21.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/99/99.NIMR31.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/277/277.NIMR51.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/407/407.NIMR61.DAT
# 48.NMIR21 already parsed to datafiles, skipping
# 205.NMIR41 already parsed to datafiles, skipping
# 284.nmir51 already parsed to datafiles, skipping
# 363.NMIR61 already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/205/205.NMMR41.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/284/284.nmmr51.dat
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/363/363.NMMR61.DAT
# 86.NPIR31 already parsed to datafiles, skipping
# 202.NPIR41 already parsed to datafiles, skipping
# 268.NPIR51 already parsed to datafiles, skipping
# 356.NPIR61 already parsed to datafiles, skipping
# 472.NPIR7H already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/202/202.NPMR41.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/268/268.NPMR51.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/356/356.NPMR61.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/472/472.NPMR7H.DAT
# 156.ORIR42 already parsed to datafiles, skipping
# 8.OSIR01 already parsed to datafiles, skipping
# 6.PEIR01 already parsed to datafiles, skipping
# 44.PEIR21 already parsed to datafiles, skipping
# 88.PEIR31 already parsed to datafiles, skipping
# 176.PEIR41 already parsed to datafiles, skipping
# 228.PEIR51 already parsed to datafiles, skipping
# 447.PEIR51 already parsed to datafiles, skipping
# 334.PEIR5I already parsed to datafiles, skipping
# 426.PEIR61 already parsed to datafiles, skipping
# 433.PEIR6A already parsed to datafiles, skipping
# 434.PEIR6I already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/88/88.PEMR31.DAT
# 61.PHIR31 already parsed to datafiles, skipping
# 111.PHIR3B already parsed to datafiles, skipping
# 227.PHIR41 already parsed to datafiles, skipping
# 298.PHIR52 already parsed to datafiles, skipping
# 436.PHIR61 already parsed to datafiles, skipping
# 510.PHIR71 already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/227/227.PHMR41.dat
# 156.PJIR42 already parsed to datafiles, skipping
# 34.PKIR21 already parsed to datafiles, skipping
# 273.pkir52 already parsed to datafiles, skipping
# 419.PKIR61 already parsed to datafiles, skipping
# 523.PKIR71 already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/34/34.PKMR21.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/419/419.PKMR61.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/523/523.PKMR71.DAT
# 33.PYIR21 already parsed to datafiles, skipping
# 156.RJIR42 already parsed to datafiles, skipping
# 43.RWIR21 already parsed to datafiles, skipping
# 165.RWIR41 already parsed to datafiles, skipping
# 252.RWIR53 already parsed to datafiles, skipping
# 323.RWIR5A already parsed to datafiles, skipping
# 364.RWIR61 already parsed to datafiles, skipping
# 449.RWIR6I already parsed to datafiles, skipping
# 468.RWIR70 already parsed to datafiles, skipping
# 540.RWIR7A already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/43/43.RWMR21.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/165/165.RWMR41.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/252/252.RWMR53.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/323/323.RWMR5A.DAT
# No rows were found for record type M32 in file 323.RWMR5A despite DCF specification
# No rows were found for record type M61 in file 323.RWMR5A despite DCF specification
# No rows were found for record type M71 in file 323.RWMR5A despite DCF specification
# No rows were found for record type M80 in file 323.RWMR5A despite DCF specification
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/364/364.RWMR61.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/468/468.RWMR70.DAT
# 29.SDIR02 already parsed to datafiles, skipping
# 156.SKIR42 already parsed to datafiles, skipping
# 324.SLIR51 already parsed to datafiles, skipping
# 450.SLIR61 already parsed to datafiles, skipping
# 515.SLIR72 already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/324/324.SLMR51.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/450/450.SLMR61.DAT
# 3.SNIR02 already parsed to datafiles, skipping
# 46.SNIR21 already parsed to datafiles, skipping
# 81.SNIR32 already parsed to datafiles, skipping
# 233.SNIR4A already parsed to datafiles, skipping
# 293.SNIR51 already parsed to datafiles, skipping
# 338.SNIR5A already parsed to datafiles, skipping
# 365.SNIR61 already parsed to datafiles, skipping
# 423.SNIR6D already parsed to datafiles, skipping
# 489.SNIR7H already parsed to datafiles, skipping
# 534.SNIR7Z already parsed to datafiles, skipping
# 580.SNIR80 already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/46/46.SNMR21.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/81/81.SNMR31.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/233/233.SNMR4A.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/365/365.SNMR61.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/489/489.SNMR7H.DAT
# No rows were found for record type M41 in file 489.SNMR7H despite DCF specification
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/534/534.SNMR7Z.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/580/580.SNMR80.DAT
# 318.STIR51 already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/318/318.STMR51.DAT
# 259.szir51 already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/259/259.szmr51.dat
# 83.TDIR31 already parsed to datafiles, skipping
# 215.TDIR41 already parsed to datafiles, skipping
# 465.TDIR71 already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/83/83.TDMR31.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/215/215.TDMR41.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/465/465.TDMR71.DAT
# 22.TGIR01 already parsed to datafiles, skipping
# 114.TGIR31 already parsed to datafiles, skipping
# 328.TGIR61 already parsed to datafiles, skipping
# 497.TGIR71 already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/114/114.TGMR31.DAT
# No rows were found for record type MA in file 114.TGMR31 despite DCF specification
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/328/328.TGMR61.DAT
# 13.THIR01 already parsed to datafiles, skipping
# 384.TJIR61 already parsed to datafiles, skipping
# 521.TJIR71 already parsed to datafiles, skipping
# 340.TLIR61 already parsed to datafiles, skipping
# 514.TLIR71 already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/340/340.TLMR61.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/514/514.TLMR71.DAT
# 26.TNIR02 already parsed to datafiles, skipping
# 156.TNIR42 already parsed to datafiles, skipping
# 156.TRIR42 already parsed to datafiles, skipping
# 18.TTIR01 already parsed to datafiles, skipping
# 41.TZIR21 already parsed to datafiles, skipping
# 82.TZIR3A already parsed to datafiles, skipping
# 167.TZIR41 already parsed to datafiles, skipping
# 234.tzir4a already parsed to datafiles, skipping
# 253.TZIR4I already parsed to datafiles, skipping
# 304.TZIR51 already parsed to datafiles, skipping
# 345.TZIR63 already parsed to datafiles, skipping
# 393.TZIR6A already parsed to datafiles, skipping
# 485.TZIR7B already parsed to datafiles, skipping
# 529.TZIR7I already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/41/41.TZMR21.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/82/82.TZMR3A.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/167/167.TZMR41.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/253/253.TZMR4I.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/345/345.TZMR61.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/485/485.TZMR7B.DAT
# No rows were found for record type M80 in file 485.TZMR7B despite DCF specification
# 27.UGIR01 already parsed to datafiles, skipping
# 76.UGIR33 already parsed to datafiles, skipping
# 169.ugIr41 already parsed to datafiles, skipping
# 266.UGIR52 already parsed to datafiles, skipping
# 332.UGIR5A already parsed to datafiles, skipping
# 399.UGIR61 already parsed to datafiles, skipping
# 373.UGIR6A already parsed to datafiles, skipping
# 484.UGIR72 already parsed to datafiles, skipping
# 504.UGIR7B already parsed to datafiles, skipping
# 549.UGIR7I already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/76/76.UGMR33.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/169/169.ugMr41.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/266/266.UGMR52.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/399/399.UGMR61.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/504/504.UGMR7B.DAT
# 156.UPIR42 already parsed to datafiles, skipping
# 94.UZIR31 already parsed to datafiles, skipping
# 100.VNIR31 already parsed to datafiles, skipping
# 209.VNIR41 already parsed to datafiles, skipping
# 261.VNIR52 already parsed to datafiles, skipping
# 156.WBIR42 already parsed to datafiles, skipping
# 36.YEIR21 already parsed to datafiles, skipping
# 358.YEIR61 already parsed to datafiles, skipping
# 113.ZAIR31 already parsed to datafiles, skipping
# 390.ZAIR71 already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/390/390.ZAMR71.DAT
# 51.ZMIR21 already parsed to datafiles, skipping
# 90.ZMIR31 already parsed to datafiles, skipping
# 206.zmir42 already parsed to datafiles, skipping
# 278.ZMIR51 already parsed to datafiles, skipping
# 406.ZMIR61 already parsed to datafiles, skipping
# 542.ZMIR71 already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/90/90.ZMMR31.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/206/206.ZMMR41.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/278/278.ZMMR51.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/406/406.ZMMR61.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/542/542.ZMMR71.DAT
# 21.ZWIR01 already parsed to datafiles, skipping
# 64.ZWIR31 already parsed to datafiles, skipping
# 184.ZWIR42 already parsed to datafiles, skipping
# 260.ZWIR52 already parsed to datafiles, skipping
# 367.ZWIR62 already parsed to datafiles, skipping
# 475.ZWIR72 already parsed to datafiles, skipping
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/64/64.ZWMR31.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/184/184.ZWMR41.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/260/260.ZWMR52.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/367/367.ZWMR62.DAT
# Parsing /mnt/d/InformalCities/DHS_Updates/staging/downloaded/475/475.ZWMR72.DAT
