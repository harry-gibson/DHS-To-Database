# %%
with open('config/pg_conn.txt') as conn_details:
    conn_str_psyco = conn_details.readline()
    conn_str_sqlalchemy = conn_details.readline()

# %%
import sys
sys.executable
# Out:
# '/mnt/c/Users/harry/Documents/github/DHS-DataExtraction/dhs_env/bin/python3'

# %%
import pandas as pd
import pandas.io.sql as psql
import psycopg2 as pg
from sqlalchemy import create_engine
import sqlalchemy as sa
import os
import glob

# %%
SPEC_SCHEMA = 'dhs_survey_specs'
DATA_SCHEMA = 'dhs_data_tables'

TABLESPEC_TABLENAME = 'table_specs_blank' #'dhs_table_specs_flat'
VALUESPEC_TABLENAME = 'value_specs_blank' #'dhs_value_descs'
SURVEYLIST_TABLENAME = 'dhs_survey_listing_backup'

TABLE_SPEC_TABLE = ".".join((SPEC_SCHEMA, TABLESPEC_TABLENAME))
VALUE_SPEC_TABLE = ".".join((SPEC_SCHEMA, VALUESPEC_TABLENAME))
SURVEYLIST_TABLE = ".".join((SPEC_SCHEMA, SURVEYLIST_TABLENAME))

STAGING_FOLDER = "/mnt/d/InformalCities/DHS_Updates/staging"

# %%
engine = create_engine(conn_str_sqlalchemy)

# %% [markdown]
# # Part 1 - refresh DB cache of available surveys

# %% [markdown]
# Load the list of all surveys from the DHS API. Note that in the past, this has been paginated, necessitating multiple calls to load it all. At present this isn't the case. As at 2021-01-08 there are 444 rows returned, so if you note less than this then it's likely pagination has been re-implemented.

# %%
api_survey_listing = pd.read_csv('http://api.dhsprogram.com/rest/dhs/surveys?f=csv&surveyStatus=all&perpage=2000')
api_survey_listing.columns = api_survey_listing.columns.str.lower()
api_survey_listing.head()
# Out:
#     surveyid dhs_countrycode  surveyyear surveytype surveystatus  countryname  \
# 0  AF2010OTH              AF        2010        OTH    Completed  Afghanistan
# 1  AF2015DHS              AF        2015        DHS    Completed  Afghanistan
# 2  AF2018SPA              AF        2018        SPA    Completed  Afghanistan
# 3  AF2020DHS              AF        2020        DHS      Ongoing  Afghanistan
# 4  AL2008DHS              AL        2008        DHS    Completed      Albania
#
#   surveyyearlabel  surveynum  indicatordata                     regionname  \
# 0            2010        348              0         South & Southeast Asia
# 1            2015        471              1         South & Southeast Asia
# 2         2018-19        543              0         South & Southeast Asia
# 3            2020        568              0         South & Southeast Asia
# 4         2008-09        327              1  North Africa/West Asia/Europe
#
#    ... numberofhouseholds     universeofwomen numberofwomen minagewomen  \
# 0  ...            22351.0  Ever Married Women       47848.0        12.0
# 1  ...            24395.0  Ever Married Women       29461.0        15.0
# 2  ...                NaN                 NaN           NaN         NaN
# 3  ...            33120.0  Ever Married Women       37146.0        15.0
# 4  ...             7999.0           All Women        7584.0        15.0
#
#   maxagewomen     universeofmen numberofmen minagemen  maxagemen  \
# 0        49.0               NaN         NaN       NaN        NaN
# 1        49.0  Ever Married Men     10760.0      15.0       49.0
# 2         NaN               NaN         NaN       NaN        NaN
# 3        49.0  Ever Married Men     13672.0      15.0       49.0
# 4        49.0           All Men      3013.0      15.0       49.0
#
#    numberoffacilities
# 0                 NaN
# 1                 NaN
# 2               142.0
# 3                 NaN
# 4                 NaN
#
# [5 rows x 29 columns]

# %%
our_survey_listing = pd.read_sql(f'SELECT * from {SURVEYLIST_TABLE}', con=engine)

# %% [markdown]
# See if there's any in the API results that aren't in our DB copy of the table

# %%
api_survey_listing[~api_survey_listing['surveynum'].isin(our_survey_listing['surveynum'])]
# Out:
# Empty DataFrame
# Columns: [surveyid, dhs_countrycode, surveyyear, surveytype, surveystatus, countryname, surveyyearlabel, surveynum, indicatordata, regionname, subregionname, publicationdate, releasedate, surveycharacteristicids, footnotes, fieldworkstart, fieldworkend, implementingorg, numberofsamplepoints, numberofhouseholds, universeofwomen, numberofwomen, minagewomen, maxagewomen, universeofmen, numberofmen, minagemen, maxagemen, numberoffacilities]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# If there's more in the API than our copy of the table, just drop and reload the whole table.

# %%
if len(api_survey_listing) > len(our_survey_listing):
    api_survey_listing.to_sql(name=SURVEYLIST_TABLENAME, con=engine, schema=SPEC_SCHEMA, 
                     index=False, if_exists='replace', method='multi')

# %% [markdown]
# # Part 2 - Update the database survey metadata tables
#
# The database has one metadata table which records all the survey data tables and what columns they have (per survey). This contains the values from the parsed "FlatRecordSpec" csv files.
#
# Another metadata table records all the values that all the survey data table columns can take, and (in the case of coded values) what the numeric values mean. This contains the values from the parsed "FlatValuesSpec" files.
#
# For every CSV FlatRecordSpec and FlatValuesSpec file, we need to check if it's in the DB table at all (and load if not). If it is already there, then check if the info in the latest CSV matches what's in the DB. (As e.g. a re-released survey may change the specified width of some columns, or add some new data tables equating to extra metadata rows).

# %%
from lib03_Update_Metadata import SurveyMetadataHelper

# %%
db_helper = SurveyMetadataHelper(conn_str=conn_str_sqlalchemy, table_spec_table=TABLESPEC_TABLENAME,
                             value_spec_table=VALUESPEC_TABLENAME, spec_schema=SPEC_SCHEMA)

# %% [markdown]
# Get a simple list of all the surveys that appear in the database metadata tables at all

# %%
existing_table_svys = db_helper.get_existing_table_surveys()
existing_value_svys = db_helper.get_existing_value_surveys()

# %%
existing_table_svys['surveyid'].values[:10]
# Out:
# array(['462', '497', '521', '383', '13', '93', '391', '94', '34', '115'],
#       dtype=object)

# %% [markdown]
# Get a listing of all the up-to-date CSV table and value specification files we've parsed

# %%
spec_csv_dir = os.path.join(STAGING_FOLDER, 'parsed_specs')

tbl_files = glob.glob(os.path.join(spec_csv_dir, '*.FlatRecordSpec.csv'))
val_files = glob.glob(os.path.join(spec_csv_dir, '*.FlatValuesSpec.csv'))

# %%
tbl_files[:5]
# Out:
# ['/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/1.ESIR01.FlatRecordSpec.csv',
#  '/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/100.VNIR31.FlatRecordSpec.csv',
#  '/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/101.CMIR31.FlatRecordSpec.csv',
#  '/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/101.CMMR31.FlatRecordSpec.csv',
#  '/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/105.MZIR31.FlatRecordSpec.csv']

# %% [markdown]
# Each survey may have more than one file. This is normal if one is "individual recode" and another is "men's recode", but if there's some other reason then we need to investigate.
#
# Create a list of all the files for each (numerically-identified) survey id

# %%
tbl_files_dict = build_spec_files_dict(tbl_files)
val_files_dict = build_spec_files_dict(val_files)

# %% [markdown]
# Check we don't have anything we weren't expecting

# %%
multiple_locs = set()
multiple_versions_per_filetype = set() # TODO
unknown_filetypes = set()
multiple_files_per_filetype = set()

for surveyid, dict_type_filenames in tbl_files_dict.items():
    survey_loc = None
    survey_version = {'ir':None, 'mr':None}
    types_this_survey = set()
    for filetype, fn_ver_locs in dict_type_filenames.items():
        
        # check we don't have anything except for IR and MR datasets
        if filetype not in ['ir', 'mr']:
            unknown_filetypes.add(surveyid)
        
        # check we don't have more than one IR or MR per survey
        # if we do, then it's a new version
        if len(fn_ver_locs)>1:
            multiple_files_per_filetype.add(surveyid)
        for fn, new_version, new_loc in fn_ver_locs:
            # check for location being unique across IR and MR files
            if survey_loc is None:
                survey_loc = new_loc
            elif survey_loc != new_loc:
                multiple_locs.add(surveyid)
        
            # version string is often different between IR and MR files, that's ok, 
            # we want to check for multiple versions per filetype
            if survey_version[filetype] is None:
                survey_version[filetype] = new_version
            elif survey_version[filetype] != new_version:
                multiple_versions_per_filetype.add(surveyid)

# %% [markdown]
# Check if there are any surveys with filetypes other than IR/MR

# %%
unknown_filetypes
# Out:
# set()

# %% [markdown]
# We expect that we may have both IR and MR files for a survey. If we have more than two files per (numeric) survey then it's either due to there being different location identifiers as with 156 above, or to some different filetype other than IR/MR, or to there being multiple versions present of the same survey (e.g. if we've re-downloaded and are working in the same folder after an update was released). Check which surveys are affected by this.
#
# This shows all surveys with more than one file per filetype, could be due to multiple locations OR versions:

# %%
multiple_files_per_filetype
# Out:
# {'580'}

# %% [markdown]
# This shows those truly with multiple versions per filetype at same location. If so then we will drop and reload the latest one only. (It's also quite common for the IR and MR files to have a different version. Don't worry about this.)

# %%
multiple_versions_per_filetype
# Out:
# {'580'}

# %% [markdown]
# In the case of one survey, number 156 (India) the download contains a main data file for India nationally (IAIR42), plus one for each state. (These break the convention by which the first two characters of the filename give the country code of the survey, because they are named for the state instead e.g. the file KEIR42 does not refer to Kenya but Kerala. This is one reason why we prepend and use the numeric survey id instead.) We do not need these state-wise files.
#
# Here we check that there are no other surveys affected by this other than 156:

# %%
multiple_locs
# Out:
# set()

# %% [markdown]
# we only want to parse and load one version per filetype (IR/MR) and per survey.

# %% [markdown]
# ### Check and load/reload column spec files as necessary

# %%
good_tbl_svys = []
drop_tbl_svys = []
new_tbl_svys = []

good_val_svys = []
reload_val_svys = []
new_val_svys = []

for surveyid, dict_type_filenames in tbl_files_dict.items():
    some_only_in_csv = False
    some_only_in_db = False
    
    locset = set()
    has_dupes = False
    for file_type, fn_ver_locs in dict_type_filenames.items():
        for _, _, loc in fn_ver_locs:
            locset.add(loc)
        if len(locset)>1:
            warnings.warn(f"""
            ****** WARNING MULTIPLE LOCATIONS FOUND FOR SURVEYID {surveyid} FILETYPE {file_type}. CANNOT DETERMINE WHICH TO LOAD *****
            ****** PLEASE REMOVE SURPLUS FILES AND RERUN FOR THIS WHOLE SURVEY*****
            """)
            has_dupes = True
    if has_dupes:
        continue
        
    # shortcut other checks, if nothing for this survey is in DB at all then we definitely need to load
    need_to_load_all_data = surveyid not in existing_table_svys.values
    if need_to_load_all_data: # no files or part files from this svy loaded
        for file_type, fn_ver_locs in dict_type_filenames.items():
            # the versions are strings such as '70' or '7A' where the first character 
            # represents the phase (fixed for a survey) and the second the actual version 
            # of this file. Anyway, natural sort order by version is ok.
            latest = sorted(fn_ver_locs, key=lambda tup: tup[1])[-1]
            file_name, file_ver, file_loc = latest
            print(f"No data for survey {surveyid} are present: "+
                  "loading latest data for {file_type.upper()} from {file_name}")
            if len(fn_ver_locs) > 1: print(f"   ({len(fn_ver_locs)} versions were available, loading {file_ver}")
            db_helper.load_new_metadata_file(file_name)
        continue
    
    # metadata for this survey are already present. That doesn't necessarily mean we don't need to 
    # load or reload this file. Check.
    for file_type, fn_ver_locs in dict_type_filenames.items():
        latest = sorted(fn_ver_locs, key=lambda tup: tup[1])[-1]
        file_name, file_ver, file_loc = latest
        
        # Check for the scenario where IR data are in the DB but MR data aren't, etc
        if not db_helper.get_any_in_db_cols(surveyid, file_type):
            print(f"{file_type.upper()} data for survey {surveyid} are not present: loading from {file_name}")
            if len(fn_ver_locs) > 1: print(f"    (of {len(fn_ver_locs)} available versions)")
            db_helper.load_new_metadata_file(file_name)
            continue
            
        db_ver, db_has_single_ver = db_helper.get_db_survey_version_cols(surveyid, file_type)
        if not db_has_single_ver:
            db_helper.drop_and_reload(file_name, 
                                      msg="Multiple versions found in DB, dropping all and loading latest")
        elif file_ver > db_ver:
            # this needs to be done for the data tables too
            db_helper.drop_and_reload(file_name, 
                                      msg=f"Newer version found - DB is version {db_ver} "+
                                      "and file is version {file_ver}")
        else:
            # check that the same rows are present in the CSV and DB
            file_cols_data = pd.read_csv(file_name)
            db_cols_data = db_helper.get_tablespec_rows_for_svy_filetype(surveyid, file_type)
            # do an outer join to find items present in files but not DB and vice versa
            merged_cols = file_cols_data.merge(db_cols_data, how='outer',
                                      left_on=['Name','RecordName','Label','Len'],
                                      right_on=['name','recordname', 'label', 'len'],
                                      suffixes=('_new', '_exist'),
                                      indicator=True)
            cols_all_good = len(merged_cols[merged_cols['_merge']!='both']) == 0
            if not cols_all_good:
                # Most likely reason for having new columns info is that we've added men's recode data,
                # but that won't be the case here as the check included filetype.
                # Reasons to be here would be it's a re-issued survey (same id number) and has added 
                # different columns (in which case there will be some left-only and no right-only ones), 
                # and/or that some column labels have changed (e.g. prefix of NA been added).
                some_only_in_db = len(merged_cols[merged_cols['_merge'] == 'right_only']) > 0
                some_only_in_csv = len(merged_cols[merged_cols['_merge'] == 'left_only']) > 0
                if some_only_in_csv and some_only_in_db:
                    # Not worth the effort to investigate: just drop everything from this survey and reload.
                    db_helper.drop_and_reload(file_name, 
                                              msg="Rows mismatch between file and DB")
                elif some_only_in_csv:
                    # Not worth the effort to investigate: just drop everything from this survey and reload.
                    db_helper.drop_and_reload(file_name, 
                                              msg="Rows present in file but not in DB")
                elif some_only_in_db:
                    # Not worth the effort to investigate: just drop everything from this survey and reload.
                    db_helper.drop_and_reload(file_name, 
                                              msg="Rows present in DB but not in file")
            else:
                pass
                #report_cols_all_good(surveyid, file_type, file_name)

# %% [markdown]
# ### Check and load/reload value spec files as necessary

# %%
good_tbl_svys = []
drop_tbl_svys = []
new_tbl_svys = []

good_val_svys = []
reload_val_svys = []
new_val_svys = []

for surveyid, dict_type_filenames in val_files_dict.items():
    #if not surveyid.startswith('1'):
    #    continue
    some_only_in_csv = False
    some_only_in_db = False
    #if surveyid != '16':
     #   continue
    
    locset = set()
    has_dupes = False
    for file_type, fn_ver_locs in dict_type_filenames.items():
        for _, _, loc in fn_ver_locs:
            locset.add(loc)
        if len(locset)>1:
            print(f"""
            ****** WARNING MULTIPLE LOCATIONS FOUND FOR SURVEYID {surveyid} FILETYPE {file_type}. CANNOT DETERMINE WHICH TO LOAD *****
            ****** PLEASE REMOVE SURPLUS FILES AND RERUN FOR THIS WHOLE SURVEY*****
            """)
            has_dupes = True
    if has_dupes:
        continue
        
    # shortcut other checks, if nothing for this survey is in DB at all then we definitely need to load
    need_to_load_all_data = surveyid not in existing_value_svys.values
    if need_to_load_all_data: # no files or part files from this svy loaded
        for file_type, fn_ver_locs in dict_type_filenames.items():
            # the versions are strings such as '70' or '7A' where the first character 
            # represents the phase (fixed for a survey) and the second the actual version 
            # of this file. Anyway, natural sort order by version is ok.
            latest = sorted(fn_ver_locs, key=lambda tup: tup[1])[-1]
            file_name, file_ver, file_loc = latest
            print(f"No data for survey {surveyid} are present: "+
                  "loading latest data for {file_type.upper()} from {file_name}")
            if len(fn_ver_locs) > 1: print(f"   ({len(fn_ver_locs)} versions were available, loading {file_ver}")
            db_helper.load_new_metadata_file(file_name)
        continue
            
    for file_type, fn_ver_locs in dict_type_filenames.items():
        latest = sorted(fn_ver_locs, key=lambda tup: tup[1])[-1]
        file_name, file_ver, file_loc = latest
        
        # Check for the scenario where IR data are in the DB but MR data aren't, etc
        if not get_any_in_db_vals(surveyid, file_type):
            print(f"{file_type.upper()} value-spec data for survey {surveyid} are not present: loading from {file_name}")
            if len(fn_ver_locs) > 1: print(f"    (of {len(fn_ver_locs)} available versions)")
            db_helper.load_new_metadata_file(file_name)
            continue
            
        db_ver, db_has_single_ver = get_db_survey_version_vals(surveyid, file_type)
        if not db_has_single_ver:
            db_helper.drop_and_reload(file_name,
                            msg="Multiple versions found in DB, dropping all and loading latest")
        elif file_ver > db_ver:
            # this needs to be done for the data tables too
            db_helper.drop_and_reload(file_name,
                            msg=f"Newer version found - DB is version {db_ver} "+
                                      "and file is version {file_ver}")
        else:
            # check that the same rows are present in the CSV and DB
            file_vals_data = pd.read_csv(file_name)
            db_vals_data = db_helper.get_valuespec_rows_for_svy_filetype(surveyid, file_type)
            # do an outer join to find items present in files but not DB and vice versa
            merged_vals = file_vals_data.merge(db_vals_data, how='outer',
                                      left_on=['Name','Value','ValueDesc','ValueType'],
                                      right_on=['col_name','value', 'value_desc', 'value_type'],
                                      suffixes=('_new', '_exist'),
                                      indicator=True)
            vals_all_good = len(merged_vals[merged_vals['_merge']!='both']) == 0
            if not vals_all_good:
                # Most likely reason is that we now have men's recode data as well, but did not previously, 
                # but we have checked for that already.
                # Other reasons would be it's a re-issued survey (same id number) and has added different columns 
                # (in which case there will be some left-only and no right-only ones), and/or that some column 
                # labels have changed (e.g. prefix of NA been added).
                some_only_in_db = len(merged_vals[merged_vals['_merge'] == 'right_only']) > 0
                some_only_in_csv = len(merged_vals[merged_vals['_merge'] == 'left_only']) > 0
                if some_only_in_csv and some_only_in_db:
                    # Not worth the effort to investigate: just drop everything from this survey and reload.
                    db_helper.drop_and_reload(file_name, 
                                              msg="Rows mismatch between file and DB")
                elif some_only_in_csv:
                    # Not worth the effort to investigate: just drop everything from this survey and reload.
                    db_helper.drop_and_reload(file_name, 
                                              msg="Rows present in file but not in DB")
                elif some_only_in_db:
                    # Not worth the effort to investigate: just drop everything from this survey and reload.
                    db_helper.drop_and_reload(file_name, 
                                              msg="Rows present in DB but not in file")
                    
            else:
                pass
                #report_vals_all_good(surveyid, file_type, file_name)
# Out:
# Survey 1 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/1.ESIR01.FlatValuesSpec.csv) is already completely loaded
# Survey 100 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/100.VNIR31.FlatValuesSpec.csv) is already completely loaded
# Survey 101 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/101.CMIR31.FlatValuesSpec.csv) is already completely loaded
# Survey 101 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/101.CMMR31.FlatValuesSpec.csv) is already completely loaded
# Survey 105 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/105.MZIR31.FlatValuesSpec.csv) is already completely loaded
# Survey 105 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/105.MZMR31.FlatValuesSpec.csv) is already completely loaded
# Survey 106 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/106.CIIR3A.FlatValuesSpec.csv) is already completely loaded
# Survey 106 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/106.CIMR3A.FlatValuesSpec.csv) is already completely loaded
# Survey 109 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/109.KYIR31.FlatValuesSpec.csv) is already completely loaded
# Survey 11 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/11.MXIR01.FlatValuesSpec.csv) is already completely loaded
# Survey 110 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/110.MDIR31.FlatValuesSpec.csv) is already completely loaded
# Survey 111 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/111.PHIR3B.FlatValuesSpec.csv) is already completely loaded
# Survey 112 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/112.NCIR31.FlatValuesSpec.csv) is already completely loaded
# Survey 112 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/112.NCMR31.FlatValuesSpec.csv) is already completely loaded
# Survey 113 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/113.ZAIR31.FlatValuesSpec.csv) is already completely loaded
# Survey 114 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/114.TGIR31.FlatValuesSpec.csv) is already completely loaded
# Survey 114 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/114.TGMR31.FlatValuesSpec.csv) is already completely loaded
# Survey 115 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/115.KEIR3A.FlatValuesSpec.csv) is already completely loaded
# Survey 115 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/115.KEMR3A.FlatValuesSpec.csv) is already completely loaded
# Survey 116 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/116.BFIR31.FlatValuesSpec.csv) is already completely loaded
# Survey 116 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/116.BFMR31.FlatValuesSpec.csv) is already completely loaded
# Survey 12 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/12.MLIR01.FlatValuesSpec.csv) is already completely loaded
# Survey 13 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/13.THIR01.FlatValuesSpec.csv) is already completely loaded
# Survey 135 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/135.BDMR41.FlatValuesSpec.csv) is already completely loaded
# Survey 14 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/14.IDIR01.FlatValuesSpec.csv) is already completely loaded
# Survey 140 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/140.KHIR42.FlatValuesSpec.csv) is already completely loaded
# Survey 141 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/141.COIR41.FlatValuesSpec.csv) is already completely loaded
# Survey 142 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/142.DRIR41.FlatValuesSpec.csv) is already completely loaded
# Survey 142 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/142.DRMR41.FlatValuesSpec.csv) is already completely loaded
# Survey 145 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/145.EGIR42.FlatValuesSpec.csv) is already completely loaded
# Survey 147 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/147.ETIR41.FlatValuesSpec.csv) is already completely loaded
# Survey 147 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/147.ETMR41.FlatValuesSpec.csv) is already completely loaded
# Survey 148 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/148.GAIR41.FlatValuesSpec.csv) is already completely loaded
# Survey 148 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/148.GAMR41.FlatValuesSpec.csv) is already completely loaded
# Survey 15 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/15.ECIR01.FlatValuesSpec.csv) is already completely loaded
# Survey 151 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/151.GHIR41.FlatValuesSpec.csv) is already completely loaded
# Survey 151 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/151.GHMR41.FlatValuesSpec.csv) is already completely loaded
# Survey 152 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/152.GUIR41.FlatValuesSpec.csv) is already completely loaded
# Survey 154 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/154.GNIR41.FlatValuesSpec.csv) is already completely loaded
# Survey 154 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/154.GNMR41.FlatValuesSpec.csv) is already completely loaded
# Survey 155 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/155.htIr42.FlatValuesSpec.csv) is already completely loaded
# Survey 155 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/155.htMr42.FlatValuesSpec.csv) is already completely loaded
# Survey 156 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/156.IAIR42.FlatValuesSpec.csv) is already completely loaded
# Survey 157 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/157.KKIR42.FlatValuesSpec.csv) is already completely loaded
# Survey 157 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/157.KKMR41.FlatValuesSpec.csv) is already completely loaded
# Survey 158 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/158.MWIR41.FlatValuesSpec.csv) is already completely loaded
# Survey 158 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/158.MWMR41.FlatValuesSpec.csv) is already completely loaded
# Survey 159 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/159.MLIR41.FlatValuesSpec.csv) is already completely loaded
# Survey 159 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/159.MLMR41.FlatValuesSpec.csv) is already completely loaded
# Survey 16 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/16.BUIR02.FlatValuesSpec.csv) is already completely loaded
# Survey 165 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/165.RWIR41.FlatValuesSpec.csv) is already completely loaded
# Survey 165 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/165.RWMR41.FlatValuesSpec.csv) is already completely loaded
# Survey 167 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/167.TZIR41.FlatValuesSpec.csv) is already completely loaded
# Survey 167 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/167.TZMR41.FlatValuesSpec.csv) is already completely loaded
# Survey 169 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/169.UGIR41.FlatValuesSpec.csv) is already completely loaded
# Survey 169 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/169.UGMR41.FlatValuesSpec.csv) is already completely loaded
# Survey 17 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/17.MAIR01.FlatValuesSpec.csv) is already completely loaded
# Survey 172 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/172.IDIR42.FlatValuesSpec.csv) is already completely loaded
# Survey 172 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/172.IDMR42.FlatValuesSpec.csv) is already completely loaded
# Survey 174 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/174.mzir41.FlatValuesSpec.csv) is already completely loaded
# Survey 174 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/174.mzmr41.FlatValuesSpec.csv) is already completely loaded
# Survey 176 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/176.PEIR41.FlatValuesSpec.csv) is already completely loaded
# Survey 18 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/18.TTIR01.FlatValuesSpec.csv) is already completely loaded
# Survey 184 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/184.ZWIR42.FlatValuesSpec.csv) is already completely loaded
# Survey 184 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/184.ZWMR41.FlatValuesSpec.csv) is already completely loaded
# Survey 19 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/19.LKIR02.FlatValuesSpec.csv) is already completely loaded
# Survey 2 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/2.BRIR01.FlatValuesSpec.csv) is already completely loaded
# Survey 20 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/20.KEIR03.FlatValuesSpec.csv) is already completely loaded
# Survey 202 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/202.NPIR41.FlatValuesSpec.csv) is already completely loaded
# Survey 202 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/202.NPMR41.FlatValuesSpec.csv) is already completely loaded
# Survey 204 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/204.NCIR41.FlatValuesSpec.csv) is already completely loaded
# Survey 205 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/205.NMIR41.FlatValuesSpec.csv) is already completely loaded
# Survey 205 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/205.NMMR41.FlatValuesSpec.csv) is already completely loaded
# Survey 206 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/206.zmir42.FlatValuesSpec.csv) is already completely loaded
# Survey 206 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/206.ZMMR41.FlatValuesSpec.csv) is already completely loaded
# Survey 207 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/207.MDIR42.FlatValuesSpec.csv) is already completely loaded
# Survey 207 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/207.MDMR42.FlatValuesSpec.csv) is already completely loaded
# Survey 208 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/208.JOIR42.FlatValuesSpec.csv) is already completely loaded
# Survey 209 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/209.VNIR41.FlatValuesSpec.csv) is already completely loaded
# Survey 21 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/21.ZWIR01.FlatValuesSpec.csv) is already completely loaded
# Survey 210 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/210.DRIR4B.FlatValuesSpec.csv) is already completely loaded
# Survey 210 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/210.DRMR4B.FlatValuesSpec.csv) is already completely loaded
# Survey 211 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/211.BJIR41.FlatValuesSpec.csv) is already completely loaded
# Survey 211 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/211.BJMR41.FlatValuesSpec.csv) is already completely loaded
# Survey 214 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/214.mair43.FlatValuesSpec.csv) is already completely loaded
# Survey 215 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/215.TDIR41.FlatValuesSpec.csv) is already completely loaded
# Survey 215 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/215.TDMR41.FlatValuesSpec.csv) is already completely loaded
# Survey 216 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/216.KEIR42.FlatValuesSpec.csv) is already completely loaded
# Survey 216 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/216.KEMR42.FlatValuesSpec.csv) is already completely loaded
# Survey 22 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/22.TGIR01.FlatValuesSpec.csv) is already completely loaded
# Survey 222 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/222.HTIR52.FlatValuesSpec.csv) is already completely loaded
# Survey 222 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/222.HTMR52.FlatValuesSpec.csv) is already completely loaded
# Survey 223 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/223.ngir4b.FlatValuesSpec.csv) is already completely loaded
# Survey 223 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/223.NGMR4A.FlatValuesSpec.csv) is already completely loaded
# Survey 227 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/227.PHIR41.FlatValuesSpec.csv) is already completely loaded
# Survey 227 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/227.PHMR41.FlatValuesSpec.csv) is already completely loaded
# Survey 228 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/228.PEIR51.FlatValuesSpec.csv) is already completely loaded
# Survey 230 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/230.bfir43.FlatValuesSpec.csv) is already completely loaded
# Survey 230 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/230.BFMR41.FlatValuesSpec.csv) is already completely loaded
# Survey 231 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/231.CIIR51.FlatValuesSpec.csv) is already completely loaded
# Survey 232 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/232.cmir44.FlatValuesSpec.csv) is already completely loaded
# Survey 232 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/232.cmmr44.FlatValuesSpec.csv) is already completely loaded
# Survey 233 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/233.SNIR4A.FlatValuesSpec.csv) is already completely loaded
# Survey 233 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/233.SNMR4A.FlatValuesSpec.csv) is already completely loaded
# Survey 234 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/234.TZIR4A.FlatValuesSpec.csv) is already completely loaded
# Survey 235 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/235.GHIR4B.FlatValuesSpec.csv) is already completely loaded
# Survey 235 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/235.GHMR4B.FlatValuesSpec.csv) is already completely loaded
# Survey 236 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/236.BDIR4J.FlatValuesSpec.csv) is already completely loaded
# Survey 236 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/236.BDMR4J.FlatValuesSpec.csv) is already completely loaded
# Survey 238 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/238.BOIR41.FlatValuesSpec.csv) is already completely loaded
# Survey 238 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/238.BOMR41.FlatValuesSpec.csv) is already completely loaded
# Survey 239 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/239.CDIR51.FlatValuesSpec.csv) is already completely loaded
# Survey 239 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/239.CDMR51.FlatValuesSpec.csv) is already completely loaded
# Survey 24 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/24.EGIR01.FlatValuesSpec.csv) is already completely loaded
# Survey 240 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/240.EGIR4A.FlatValuesSpec.csv) is already completely loaded
# Survey 243 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/243.GYIR51.FlatValuesSpec.csv) is already completely loaded
# Survey 248 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/248.ETIR51.FlatValuesSpec.csv) is already completely loaded
# Survey 248 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/248.ETMR51.FlatValuesSpec.csv) is already completely loaded
# Survey 249 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/249.GNIR52.FlatValuesSpec.csv) is already completely loaded
# Survey 249 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/249.gnmr52.FlatValuesSpec.csv) is already completely loaded
# Survey 25 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/25.GHIR02.FlatValuesSpec.csv) is already completely loaded
# Survey 251 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/251.MWIR4E.FlatValuesSpec.csv) is already completely loaded
# Survey 251 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/251.MWMR4E.FlatValuesSpec.csv) is already completely loaded
# Survey 252 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/252.RWIR53.FlatValuesSpec.csv) is already completely loaded
# Survey 252 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/252.RWMR53.FlatValuesSpec.csv) is already completely loaded
# Survey 253 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/253.TZIR4I.FlatValuesSpec.csv) is already completely loaded
# Survey 253 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/253.TZMR4I.FlatValuesSpec.csv) is already completely loaded
# Survey 255 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/255.COIR53.FlatValuesSpec.csv) is already completely loaded
# Survey 256 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/256.LSIR41.FlatValuesSpec.csv) is already completely loaded
# Survey 256 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/256.LSMR41.FlatValuesSpec.csv) is already completely loaded
# Survey 257 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/257.KHIR51.FlatValuesSpec.csv) is already completely loaded
# Survey 257 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/257.KHMR51.FlatValuesSpec.csv) is already completely loaded
# Survey 259 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/259.szir51.FlatValuesSpec.csv) is already completely loaded
# Survey 259 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/259.szmr51.FlatValuesSpec.csv) is already completely loaded
# Survey 26 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/26.TNIR02.FlatValuesSpec.csv) is already completely loaded
# Survey 260 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/260.ZWIR52.FlatValuesSpec.csv) is already completely loaded
# Survey 260 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/260.ZWMR52.FlatValuesSpec.csv) is already completely loaded
# Survey 261 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/261.VNIR52.FlatValuesSpec.csv) is already completely loaded
# Survey 264 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/264.IAIR52.FlatValuesSpec.csv) is already completely loaded
# Survey 264 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/264.IAMR52.FlatValuesSpec.csv) is already completely loaded
# Survey 265 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/265.HNIR52.FlatValuesSpec.csv) is already completely loaded
# Survey 266 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/266.UGIR52.FlatValuesSpec.csv) is already completely loaded
# Survey 266 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/266.UGMR52.FlatValuesSpec.csv) is already completely loaded
# Survey 267 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/267.CGIR51.FlatValuesSpec.csv) is already completely loaded
# Survey 267 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/267.CGMR51.FlatValuesSpec.csv) is already completely loaded
# Survey 268 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/268.NPIR51.FlatValuesSpec.csv) is already completely loaded
# Survey 268 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/268.NPMR51.FlatValuesSpec.csv) is already completely loaded
# Survey 27 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/27.UGIR01.FlatValuesSpec.csv) is already completely loaded
# Survey 271 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/271.LBIR51.FlatValuesSpec.csv) is already completely loaded
# Survey 271 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/271.LBMR51.FlatValuesSpec.csv) is already completely loaded
# Survey 272 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/272.EGIR51.FlatValuesSpec.csv) is already completely loaded
# Survey 273 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/273.pkir52.FlatValuesSpec.csv) is already completely loaded
# Survey 276 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/276.MLIR53.FlatValuesSpec.csv) is already completely loaded
# Survey 276 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/276.MLMR53.FlatValuesSpec.csv) is already completely loaded
# Survey 277 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/277.NIIR51.FlatValuesSpec.csv) is already completely loaded
# Survey 277 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/277.NIMR51.FlatValuesSpec.csv) is already completely loaded
# Survey 278 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/278.ZMIR51.FlatValuesSpec.csv) is already completely loaded
# Survey 278 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/278.ZMMR51.FlatValuesSpec.csv) is already completely loaded
# Survey 28 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/28.BOIR01.FlatValuesSpec.csv) is already completely loaded
# Survey 282 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/282.AOIR51.FlatValuesSpec.csv) is already completely loaded
# Survey 284 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/284.nmir51.FlatValuesSpec.csv) is already completely loaded
# Survey 284 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/284.nmmr51.FlatValuesSpec.csv) is already completely loaded
# Survey 287 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/287.BDIR51.FlatValuesSpec.csv) is already completely loaded
# Survey 287 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/287.BDMR51.FlatValuesSpec.csv) is already completely loaded
# Survey 289 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/289.BJIR51.FlatValuesSpec.csv) is already completely loaded
# Survey 289 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/289.BJMR51.FlatValuesSpec.csv) is already completely loaded
# Survey 29 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/29.SDIR02.FlatValuesSpec.csv) is already completely loaded
# Survey 291 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/291.DRIR52.FlatValuesSpec.csv) is already completely loaded
# Survey 291 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/291.DRMR52.FlatValuesSpec.csv) is already completely loaded
# Survey 293 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/293.SNIR51.FlatValuesSpec.csv) is already completely loaded
# Survey 294 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/294.EGIR5A.FlatValuesSpec.csv) is already completely loaded
# Survey 295 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/295.JOIR51.FlatValuesSpec.csv) is already completely loaded
# Survey 296 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/296.MDIR51.FlatValuesSpec.csv) is already completely loaded
# Survey 296 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/296.MDMR51.FlatValuesSpec.csv) is already completely loaded
# Survey 297 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/297.IDIR51.FlatValuesSpec.csv) is already completely loaded
# Survey 297 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/297.IDMR51.FlatValuesSpec.csv) is already completely loaded
# Survey 298 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/298.PHIR52.FlatValuesSpec.csv) is already completely loaded
# Survey 3 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/3.SNIR02.FlatValuesSpec.csv) is already completely loaded
# Survey 30 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/30.coir22.FlatValuesSpec.csv) is already completely loaded
# Survey 300 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/300.KEIR52.FlatValuesSpec.csv) is already completely loaded
# Survey 300 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/300.KEMR52.FlatValuesSpec.csv) is already completely loaded
# Survey 301 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/301.GHIR5A.FlatValuesSpec.csv) is already completely loaded
# Survey 301 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/301.GHMR5A.FlatValuesSpec.csv) is already completely loaded
# Survey 302 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/302.NGIR53.FlatValuesSpec.csv) is already completely loaded
# Survey 302 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/302.NGMR52.FlatValuesSpec.csv) is already completely loaded
# Survey 304 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/304.TZIR51.FlatValuesSpec.csv) is already completely loaded
# Survey 309 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/309.GYIR5I.FlatValuesSpec.csv) is already completely loaded
# Survey 309 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/309.GYMR5I.FlatValuesSpec.csv) is already completely loaded
# Survey 31 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/31.JOIR21.FlatValuesSpec.csv) is already completely loaded
# Survey 310 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/310.KHIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 310 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/310.KHMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 311 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/311.CIIR62.FlatValuesSpec.csv) is already completely loaded
# Survey 311 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/311.CIMR62.FlatValuesSpec.csv) is already completely loaded
# Survey 317 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/317.LSIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 317 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/317.LSMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 318 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/318.STIR51.FlatValuesSpec.csv) is already completely loaded
# Survey 318 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/318.STMR51.FlatValuesSpec.csv) is already completely loaded
# Survey 319 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/319.BOIR51.FlatValuesSpec.csv) is already completely loaded
# Survey 319 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/319.BOMR51.FlatValuesSpec.csv) is already completely loaded
# Survey 32 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/32.NGIR21.FlatValuesSpec.csv) is already completely loaded
# Survey 322 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/322.MZIR51.FlatValuesSpec.csv) is already completely loaded
# Survey 323 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/323.RWIR5A.FlatValuesSpec.csv) is already completely loaded
# Survey 323 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/323.RWMR5A.FlatValuesSpec.csv) is already completely loaded
# Survey 324 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/324.SLIR51.FlatValuesSpec.csv) is already completely loaded
# Survey 324 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/324.SLMR51.FlatValuesSpec.csv) is already completely loaded
# Survey 328 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/328.TGIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 328 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/328.TGMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 329 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/329.BFIR62.FlatValuesSpec.csv) is already completely loaded
# Survey 329 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/329.BFMR62.FlatValuesSpec.csv) is already completely loaded
# Survey 33 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/33.PYIR21.FlatValuesSpec.csv) is already completely loaded
# Survey 330 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/330.LBIR5A.FlatValuesSpec.csv) is already completely loaded
# Survey 331 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/331.DRIR5A.FlatValuesSpec.csv) is already completely loaded
# Survey 331 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/331.DRMR5A.FlatValuesSpec.csv) is already completely loaded
# Survey 332 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/332.UGIR5A.FlatValuesSpec.csv) is already completely loaded
# Survey 333 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/333.MWIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 333 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/333.MWMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 334 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/334.PEIR5I.FlatValuesSpec.csv) is already completely loaded
# Survey 336 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/336.JOIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 337 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/337.CMIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 337 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/337.CMMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 338 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/338.SNIR5A.FlatValuesSpec.csv) is already completely loaded
# Survey 34 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/34.PKIR21.FlatValuesSpec.csv) is already completely loaded
# Survey 34 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/34.PKMR21.FlatValuesSpec.csv) is already completely loaded
# Survey 340 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/340.TLIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 340 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/340.TLMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 345 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/345.TZIR63.FlatValuesSpec.csv) is already completely loaded
# Survey 345 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/345.TZMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 346 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/346.BUIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 346 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/346.BUMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 349 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/349.BDIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 349 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/349.BDMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 35 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/35.IDIR21.FlatValuesSpec.csv) is already completely loaded
# Survey 355 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/355.IAIR74.FlatValuesSpec.csv) is already completely loaded
# Survey 355 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/355.IAMR74.FlatValuesSpec.csv) is already completely loaded
# Survey 356 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/356.NPIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 356 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/356.NPMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 357 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/357.IDIR63.FlatValuesSpec.csv) is already completely loaded
# Survey 357 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/357.IDMR63.FlatValuesSpec.csv) is already completely loaded
# Survey 358 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/358.YEIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 359 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/359.ETIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 359 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/359.ETMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 36 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/36.YEIR21.FlatValuesSpec.csv) is already completely loaded
# Survey 361 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/361.LBIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 362 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/362.MZIR62.FlatValuesSpec.csv) is already completely loaded
# Survey 362 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/362.MZMR62.FlatValuesSpec.csv) is already completely loaded
# Survey 363 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/363.NMIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 363 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/363.NMMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 364 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/364.RWIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 364 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/364.RWMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 365 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/365.SNIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 365 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/365.SNMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 367 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/367.ZWIR62.FlatValuesSpec.csv) is already completely loaded
# Survey 367 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/367.ZWMR62.FlatValuesSpec.csv) is already completely loaded
# Survey 368 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/368.HTIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 368 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/368.HTMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 369 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/369.HNIR62.FlatValuesSpec.csv) is already completely loaded
# Survey 369 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/369.HNMR62.FlatValuesSpec.csv) is already completely loaded
# Survey 37 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/37.DRIR21.FlatValuesSpec.csv) is already completely loaded
# Survey 370 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/370.CGIR5A.FlatValuesSpec.csv) is already completely loaded
# Survey 373 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/373.UGIR6A.FlatValuesSpec.csv) is already completely loaded
# Survey 38 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/38.CMIR22.FlatValuesSpec.csv) is already completely loaded
# Survey 38 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/38.CMMR21.FlatValuesSpec.csv) is already completely loaded
# Survey 381 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/381.COIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 383 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/383.KYIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 383 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/383.KYMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 384 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/384.TJIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 388 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/388.CGIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 388 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/388.CGMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 390 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/390.ZAIR71.FlatValuesSpec.csv) is already completely loaded
# Survey 390 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/390.ZAMR71.FlatValuesSpec.csv) is already completely loaded
# Survey 391 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/391.GNIR62.FlatValuesSpec.csv) is already completely loaded
# Survey 391 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/391.GNMR62.FlatValuesSpec.csv) is already completely loaded
# Survey 392 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/392.NGIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 393 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/393.TZIR6A.FlatValuesSpec.csv) is already completely loaded
# Survey 395 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/395.AOIR62.FlatValuesSpec.csv) is already completely loaded
# Survey 396 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/396.MDIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 397 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/397.EGIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 399 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/399.UGIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 399 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/399.UGMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 4 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/4.COIR01.FlatValuesSpec.csv) is already completely loaded
# Survey 40 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/40.BRIR21.FlatValuesSpec.csv) is already completely loaded
# Survey 402 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/402.GAIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 402 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/402.GAMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 403 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/403.JOIR6C.FlatValuesSpec.csv) is already completely loaded
# Survey 405 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/405.MLIR6A.FlatValuesSpec.csv) is already completely loaded
# Survey 405 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/405.MLMR6A.FlatValuesSpec.csv) is already completely loaded
# Survey 406 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/406.ZMIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 406 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/406.ZMMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 407 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/407.NIIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 407 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/407.NIMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 41 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/41.TZIR21.FlatValuesSpec.csv) is already completely loaded
# Survey 41 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/41.TZMR21.FlatValuesSpec.csv) is already completely loaded
# Survey 419 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/419.PKIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 419 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/419.PKMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 42 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/42.BFIR21.FlatValuesSpec.csv) is already completely loaded
# Survey 42 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/42.BFMR21.FlatValuesSpec.csv) is already completely loaded
# Survey 420 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/420.BJIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 420 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/420.BJMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 421 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/421.CDIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 421 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/421.CDMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 423 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/423.SNIR6D.FlatValuesSpec.csv) is already completely loaded
# Survey 425 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/425.GMIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 425 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/425.GMMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 426 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/426.PEIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 43 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/43.RWIR21.FlatValuesSpec.csv) is already completely loaded
# Survey 43 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/43.RWMR21.FlatValuesSpec.csv) is already completely loaded
# Survey 432 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/432.MWIR6A.FlatValuesSpec.csv) is already completely loaded
# Survey 433 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/433.PEIR6A.FlatValuesSpec.csv) is already completely loaded
# Survey 434 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/434.PEIR6I.FlatValuesSpec.csv) is already completely loaded
# Survey 435 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/435.LBIR6A.FlatValuesSpec.csv) is already completely loaded
# Survey 435 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/435.LBMR6A.FlatValuesSpec.csv) is already completely loaded
# Survey 436 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/436.PHIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 437 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/437.GHIR72.FlatValuesSpec.csv) is already completely loaded
# Survey 437 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/437.GHMR71.FlatValuesSpec.csv) is already completely loaded
# Survey 438 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/438.NGIR6A.FlatValuesSpec.csv) is already completely loaded
# Survey 438 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/438.NGMR6A.FlatValuesSpec.csv) is already completely loaded
# Survey 439 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/439.DRIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 439 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/439.DRMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 44 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/44.PEIR21.FlatValuesSpec.csv) is already completely loaded
# Survey 440 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/440.GUIR71.FlatValuesSpec.csv) is already completely loaded
# Survey 440 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/440.GUMR71.FlatValuesSpec.csv) is already completely loaded
# Survey 443 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/443.KMIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 443 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/443.KMMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 446 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/446.BUIR6A.FlatValuesSpec.csv) is already completely loaded
# Survey 447 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/447.PEIR51.FlatValuesSpec.csv) is already completely loaded
# Survey 449 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/449.RWIR6I.FlatValuesSpec.csv) is already completely loaded
# Survey 45 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/45.EGIR21.FlatValuesSpec.csv) is already completely loaded
# Survey 450 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/450.SLIR61.FlatValuesSpec.csv) is already completely loaded
# Survey 450 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/450.SLMR61.FlatValuesSpec.csv) is already completely loaded
# Survey 451 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/451.KEIR72.FlatValuesSpec.csv) is already completely loaded
# Survey 451 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/451.KEMR72.FlatValuesSpec.csv) is already completely loaded
# Survey 454 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/454.MMIR71.FlatValuesSpec.csv) is already completely loaded
# Survey 454 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/454.MMMR71.FlatValuesSpec.csv) is already completely loaded
# Survey 456 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/456.MDIR6A.FlatValuesSpec.csv) is already completely loaded
# Survey 457 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/457.SNIR70.FlatValuesSpec.csv) is already completely loaded
# Survey 46 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/46.SNIR21.FlatValuesSpec.csv) is already completely loaded
# Survey 46 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/46.SNMR21.FlatValuesSpec.csv) is already completely loaded
# Survey 461 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/461.BDIR72.FlatValuesSpec.csv) is already completely loaded
# ...
# Survey 523 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/523.PKMR71.FlatValuesSpec.csv) is already completely loaded
# Survey 526 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/526.BFIR7A.FlatValuesSpec.csv) is already completely loaded
# Survey 527 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/527.MZIR7A.FlatValuesSpec.csv) is already completely loaded
# Survey 528 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/528.NGIR7A.FlatValuesSpec.csv) is already completely loaded
# Survey 528 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/528.NGMR7A.FlatValuesSpec.csv) is already completely loaded
# Survey 529 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/529.TZIR7I.FlatValuesSpec.csv) is already completely loaded
# Survey 53 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/53.NIIR22.FlatValuesSpec.csv) is already completely loaded
# Survey 53 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/53.NIMR21.FlatValuesSpec.csv) is already completely loaded
# Survey 534 IR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/534.SNIR7Z.FlatValuesSpec.csv) is already completely loaded
# Survey 534 MR values file (/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/534.SNMR7Z.FlatValuesSpec.csv) is already completely loaded
# No data for survey 539 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/539.GNIR71.FlatValuesSpec.csv
# Inserting 539.GNIR71.FlatValuesSpec.csv to value_specs_blank
# No data for survey 539 are present: loading latest data for MR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/539.GNMR71.FlatValuesSpec.csv
# Inserting 539.GNMR71.FlatValuesSpec.csv to value_specs_blank
# No data for survey 540 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/540.RWIR7A.FlatValuesSpec.csv
# Inserting 540.RWIR7A.FlatValuesSpec.csv to value_specs_blank
# No data for survey 542 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/542.ZMIR71.FlatValuesSpec.csv
# Inserting 542.ZMIR71.FlatValuesSpec.csv to value_specs_blank
# No data for survey 542 are present: loading latest data for MR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/542.ZMMR71.FlatValuesSpec.csv
# Inserting 542.ZMMR71.FlatValuesSpec.csv to value_specs_blank
# No data for survey 549 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/549.UGIR7I.FlatValuesSpec.csv
# Inserting 549.UGIR7I.FlatValuesSpec.csv to value_specs_blank
# No data for survey 557 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/557.GHIR81.FlatValuesSpec.csv
# Inserting 557.GHIR81.FlatValuesSpec.csv to value_specs_blank
# No data for survey 56 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/56.KEIR33.FlatValuesSpec.csv
# Inserting 56.KEIR33.FlatValuesSpec.csv to value_specs_blank
# No data for survey 56 are present: loading latest data for MR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/56.KEMR32.FlatValuesSpec.csv
# Inserting 56.KEMR32.FlatValuesSpec.csv to value_specs_blank
# No data for survey 58 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/58.GHIR31.FlatValuesSpec.csv
# Inserting 58.GHIR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 58 are present: loading latest data for MR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/58.GHMR31.FlatValuesSpec.csv
# Inserting 58.GHMR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 580 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/580.SNIR81.FlatValuesSpec.csv
#    (2 versions were available, loading 81
# Inserting 580.SNIR81.FlatValuesSpec.csv to value_specs_blank
# No data for survey 580 are present: loading latest data for MR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/580.SNMR81.FlatValuesSpec.csv
#    (2 versions were available, loading 81
# Inserting 580.SNMR81.FlatValuesSpec.csv to value_specs_blank
# No data for survey 581 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/581.SNIR8A.FlatValuesSpec.csv
# Inserting 581.SNIR8A.FlatValuesSpec.csv to value_specs_blank
# No data for survey 581 are present: loading latest data for MR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/581.SNMR8A.FlatValuesSpec.csv
# Inserting 581.SNMR8A.FlatValuesSpec.csv to value_specs_blank
# No data for survey 59 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/59.BDIR31.FlatValuesSpec.csv
# Inserting 59.BDIR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 59 are present: loading latest data for MR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/59.BDMR31.FlatValuesSpec.csv
# Inserting 59.BDMR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 6 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/6.PEIR01.FlatValuesSpec.csv
# Inserting 6.PEIR01.FlatValuesSpec.csv to value_specs_blank
# No data for survey 61 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/61.PHIR31.FlatValuesSpec.csv
# Inserting 61.PHIR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 62 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/62.CIIR35.FlatValuesSpec.csv
# Inserting 62.CIIR35.FlatValuesSpec.csv to value_specs_blank
# No data for survey 62 are present: loading latest data for MR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/62.CIMR33.FlatValuesSpec.csv
# Inserting 62.CIMR33.FlatValuesSpec.csv to value_specs_blank
# No data for survey 63 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/63.IDIR31.FlatValuesSpec.csv
# Inserting 63.IDIR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 64 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/64.ZWIR31.FlatValuesSpec.csv
# Inserting 64.ZWIR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 64 are present: loading latest data for MR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/64.ZWMR31.FlatValuesSpec.csv
# Inserting 64.ZWMR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 65 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/65.BOIR31.FlatValuesSpec.csv
# Inserting 65.BOIR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 66 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/66.CFIR31.FlatValuesSpec.csv
# Inserting 66.CFIR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 66 are present: loading latest data for MR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/66.CFMR31.FlatValuesSpec.csv
# Inserting 66.CFMR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 69 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/69.HTIR31.FlatValuesSpec.csv
# Inserting 69.HTIR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 69 are present: loading latest data for MR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/69.HTMR31.FlatValuesSpec.csv
# Inserting 69.HTMR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 7 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/7.LBIR01.FlatValuesSpec.csv
# Inserting 7.LBIR01.FlatValuesSpec.csv to value_specs_blank
# No data for survey 70 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/70.GUIR34.FlatValuesSpec.csv
# Inserting 70.GUIR34.FlatValuesSpec.csv to value_specs_blank
# No data for survey 71 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/71.EGIR33.FlatValuesSpec.csv
# Inserting 71.EGIR33.FlatValuesSpec.csv to value_specs_blank
# No data for survey 72 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/72.COIR31.FlatValuesSpec.csv
# Inserting 72.COIR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 74 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/74.KKIR31.FlatValuesSpec.csv
# Inserting 74.KKIR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 76 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/76.UGIR33.FlatValuesSpec.csv
# Inserting 76.UGIR33.FlatValuesSpec.csv to value_specs_blank
# No data for survey 76 are present: loading latest data for MR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/76.UGMR33.FlatValuesSpec.csv
# Inserting 76.UGMR33.FlatValuesSpec.csv to value_specs_blank
# No data for survey 77 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/77.MLIR32.FlatValuesSpec.csv
# Inserting 77.MLIR32.FlatValuesSpec.csv to value_specs_blank
# No data for survey 77 are present: loading latest data for MR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/77.MLMR31.FlatValuesSpec.csv
# Inserting 77.MLMR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 8 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/8.OSIR01.FlatValuesSpec.csv
# Inserting 8.OSIR01.FlatValuesSpec.csv to value_specs_blank
# No data for survey 81 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/81.SNIR32.FlatValuesSpec.csv
# Inserting 81.SNIR32.FlatValuesSpec.csv to value_specs_blank
# No data for survey 81 are present: loading latest data for MR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/81.SNMR31.FlatValuesSpec.csv
# Inserting 81.SNMR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 82 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/82.TZIR3A.FlatValuesSpec.csv
# Inserting 82.TZIR3A.FlatValuesSpec.csv to value_specs_blank
# No data for survey 82 are present: loading latest data for MR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/82.TZMR3A.FlatValuesSpec.csv
# Inserting 82.TZMR3A.FlatValuesSpec.csv to value_specs_blank
# No data for survey 83 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/83.TDIR31.FlatValuesSpec.csv
# Inserting 83.TDIR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 83 are present: loading latest data for MR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/83.TDMR31.FlatValuesSpec.csv
# Inserting 83.TDMR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 85 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/85.BRIR31.FlatValuesSpec.csv
# Inserting 85.BRIR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 85 are present: loading latest data for MR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/85.BRMR31.FlatValuesSpec.csv
# Inserting 85.BRMR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 86 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/86.NPIR31.FlatValuesSpec.csv
# Inserting 86.NPIR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 87 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/87.BJIR31.FlatValuesSpec.csv
# Inserting 87.BJIR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 87 are present: loading latest data for MR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/87.BJMR31.FlatValuesSpec.csv
# Inserting 87.BJMR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 88 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/88.PEIR31.FlatValuesSpec.csv
# Inserting 88.PEIR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 88 are present: loading latest data for MR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/88.PEMR31.FlatValuesSpec.csv
# Inserting 88.PEMR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 89 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/89.BDIR3A.FlatValuesSpec.csv
# Inserting 89.BDIR3A.FlatValuesSpec.csv to value_specs_blank
# No data for survey 89 are present: loading latest data for MR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/89.BDMR3A.FlatValuesSpec.csv
# Inserting 89.BDMR3A.FlatValuesSpec.csv to value_specs_blank
# No data for survey 9 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/9.GUIR01.FlatValuesSpec.csv
# Inserting 9.GUIR01.FlatValuesSpec.csv to value_specs_blank
# No data for survey 90 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/90.ZMIR31.FlatValuesSpec.csv
# Inserting 90.ZMIR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 90 are present: loading latest data for MR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/90.ZMMR31.FlatValuesSpec.csv
# Inserting 90.ZMMR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 92 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/92.DRIR32.FlatValuesSpec.csv
# Inserting 92.DRIR32.FlatValuesSpec.csv to value_specs_blank
# No data for survey 92 are present: loading latest data for MR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/92.DRMR31.FlatValuesSpec.csv
# Inserting 92.DRMR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 93 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/93.KMIR32.FlatValuesSpec.csv
# Inserting 93.KMIR32.FlatValuesSpec.csv to value_specs_blank
# No data for survey 93 are present: loading latest data for MR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/93.KMMR31.FlatValuesSpec.csv
# Inserting 93.KMMR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 94 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/94.UZIR31.FlatValuesSpec.csv
# Inserting 94.UZIR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 95 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/95.IDIR3A.FlatValuesSpec.csv
# Inserting 95.IDIR3A.FlatValuesSpec.csv to value_specs_blank
# No data for survey 96 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/96.JOIR31.FlatValuesSpec.csv
# Inserting 96.JOIR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 98 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/98.BOIR3B.FlatValuesSpec.csv
# Inserting 98.BOIR3B.FlatValuesSpec.csv to value_specs_blank
# No data for survey 98 are present: loading latest data for MR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/98.BOMR3B.FlatValuesSpec.csv
# Inserting 98.BOMR3B.FlatValuesSpec.csv to value_specs_blank
# No data for survey 99 are present: loading latest data for IR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/99.NIIR31.FlatValuesSpec.csv
# Inserting 99.NIIR31.FlatValuesSpec.csv to value_specs_blank
# No data for survey 99 are present: loading latest data for MR from /mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/99.NIMR31.FlatValuesSpec.csv
# Inserting 99.NIMR31.FlatValuesSpec.csv to value_specs_blank

# %% [markdown]
# Define some placeholder functions to say what we would do in the DB

# %%
DB_TABLESPEC_COLS = ['itemtype', 'recordname', 'recordtypevalue', 'recordlabel', 'name',
       'label', 'start', 'len', 'fmetype', 'surveyid', 'id', 'filecode']
DB_VALUESPEC_COLS = ['col_name', 'value', 'value_desc', 'value_type', 'surveyid', 'id',
       'filecode']

    
def add_varchar_col_to_table(schema_name, table_name, column_name, req_width):
    sql = f"""
        ALTER TABLE {schema_name}."{table_name}" 
        ADD COLUMN {column_name.lower()} CHARACTER VARYING ({req_width})"""
    return engine.execute(sql)
    
    
                
            
def delete_table_cols_for_survey(surveyid, dry_run=True):
    if dry_run:
        print(f"Would drop all rows for survey {surveyid} from {TABLESPEC_TABLENAME}")
        drop_tbl_svys.append(surveyid)
    else:
        print(f"Dropping all rows for survey {surveyid} from {TABLESPEC_TABLENAME}")
        meta = sa.MetaData()
        tablespec_db = sa.Table(TABLESPEC_TABLENAME, meta, schema=SPEC_SCHEMA, 
                                autoload=True, autoload_with=engine)
        cond = tablespec_db.c.surveyid == surveyid
        delete = tablespec_db.delete().where(cond)  
        res = engine.execute(delete)
    #pass

    
def delete_value_entries_for_survey(surveyid, dry_run=True):
    # only drop ones for matching columns because we get different ones from the IR and MR files
    if dry_run:
        print(f"Would drop all valuespec rows for survey {surveyid} from {VALUESPEC_TABLENAME}")
    else:
        print(f"Dropping all valuespec rows for survey {surveyid} from {VALUE_SPEC_TABLENAME}")
        meta = sa.MetaData()
        tablespec_db = sa.Table(TABLESPEC_TABLENAME, meta, schema=SPEC_SCHEMA, 
                                autoload=True, autoload_with=engine)
        cond = tablespec_db.c.surveyid == surveyid
        delete = tablespec_db.delete().where(cond)  
        res = engine.execute(delete)

                
def report_cols_all_good(surveyid, file_type, file_name):
    print(f"Survey {surveyid} {file_type.upper()} spec file ({file_name}) is already completely loaded")
    good_tbl_svys.append(os.path.basename(file_name).split('.')[0])
    

def report_vals_all_good(surveyid, file_type, file_name):
    print(f"Survey {surveyid} {file_type.upper()} values file ({file_name}) is already completely loaded")
    good_val_svys.append(os.path.basename(file_name).split('.')[0])

# %%
tbl_fn = "/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/505.MDIR71.FlatRecordSpec.csv"
val_fn = "/mnt/d/InformalCities/DHS_Updates/staging/parsed_specs/505.MDIR71.FlatValuesSpec.csv"

# %% [markdown]
# # Part 3 - Work out which data tables need to be (re)loaded
#
# ### Todo: transfer to next notebook
#
# Find DHS data tables that exist in the surveys according to the (newly-updated) metadata tables, but which do not exist in the database yet

# %%
data_tables_missing = pd.read_sql(f"""
    SELECT DISTINCT recordname from {TABLE_SPEC_TABLE}
    WHERE recordname NOT IN (
        SELECT DISTINCT table_name AS recordname 
        FROM information_schema.columns
        WHERE table_schema = '{DATA_SCHEMA}')"""
        , con=engine)
data_tables_missing
# Out:
#    recordname
# 0      RECHEM
# 1     RECHAN2
# 2      MREC85
# 3           *
# 4     RECHCH1
# 5      RECHVC
# 6      MRECFG
# 7       RECHD
# 8      RECHAC
# 9     RECHAN3
# 10    RECHAN1
# 11     MREC93
# 12     RECECD
# 13     MREC99
# 14    RECHMC2
# 15    RECHFAC
# 16     MREC94
# 17     REC100
# 18    RECHDIS
# 19     MREC97
# 20     MREC98

# %% [markdown]
# Find data tables which have a JSON column - we won't check for "missing" columns on these in the same way

# %%
json_tables = pd.read_sql(f"""
    SELECT DISTINCT table_name 
    FROM information_schema.columns 
    WHERE table_schema = '{DATA_SCHEMA}' AND data_type = 'jsonb'""",
                          con=engine)   
json_tables
# Out:
#    table_name
# 0       REC91
# 1       REC94
# 2       REC95
# 3       REC97
# 4       RECH3
# 5  RECH4_json

# %% [markdown]
#  Find all data  columns which are needed, according to the metadata

# %%
data_columns_needed = pd.read_sql(f"""
    SELECT recordname, LOWER(name) AS name, MAX(len) AS maxlen 
    FROM {SPEC_SCHEMA}.{TABLESPEC_TABLENAME}
    WHERE recordname != '*'
    GROUP BY recordname, name
    ORDER BY recordname, name""", con=engine)
print(data_columns_needed.head())
print(len(data_columns_needed))
# Out:
#   recordname          name  maxlen
# 0     MREC01       mcaseid      15
# 1     MREC01  mrec01_group       5
# 2     MREC01         mv000       3
# 3     MREC01         mv001       8
# 4     MREC01         mv002       6
# 51324

# %% [markdown]
# Find all data columns which are actually present

# %%
cols_present = pd.read_sql(f"""SELECT table_name, column_name, data_type 
    FROM information_schema.columns 
    WHERE table_schema = 'dhs_data_tables' ORDER BY table_name, column_name""", con=engine)
cols_present[cols_present['table_name']=='MREC01']
# Out:
#    table_name   column_name          data_type
# 34     MREC01       mcaseid  character varying
# 35     MREC01  mrec01_group  character varying
# 36     MREC01         mv000  character varying
# 37     MREC01         mv001  character varying
# 38     MREC01         mv002  character varying
# 39     MREC01         mv003  character varying
# 40     MREC01         mv004  character varying
# 41     MREC01         mv005  character varying
# 42     MREC01         mv006  character varying
# 43     MREC01         mv007  character varying
# 44     MREC01         mv008  character varying
# 45     MREC01        mv008a  character varying
# 46     MREC01         mv009  character varying
# 47     MREC01         mv010  character varying
# 48     MREC01         mv011  character varying
# 49     MREC01         mv012  character varying
# 50     MREC01         mv013  character varying
# 51     MREC01         mv014  character varying
# 52     MREC01         mv015  character varying
# 53     MREC01         mv016  character varying
# 54     MREC01         mv021  character varying
# 55     MREC01         mv022  character varying
# 56     MREC01         mv023  character varying
# 57     MREC01         mv024  character varying
# 58     MREC01         mv025  character varying
# 59     MREC01         mv026  character varying
# 60     MREC01         mv027  character varying
# 61     MREC01         mv028  character varying
# 62     MREC01         mv029  character varying
# 63     MREC01         mv030  character varying
# 64     MREC01         mv031  character varying
# 65     MREC01         mv032  character varying
# 66     MREC01         mv034  character varying
# 67     MREC01        mv034a  character varying
# 68     MREC01        mv034b  character varying
# 69     MREC01         mv035  character varying
# 70     MREC01        mv045a  character varying
# 71     MREC01        mv045b  character varying
# 72     MREC01        mv045c  character varying
# 73     MREC01         mv046  character varying
# 74     MREC01         mv801  character varying
# 75     MREC01         mv802  character varying
# 76     MREC01         mv803  character varying
# 77     MREC01      surveyid  character varying

# %% [markdown]
# Eliminate step-by-step (for clarity) to figure out which if any need adding to the data tables.
#
# First eliminate everything that does exist in the tables. NB we are only checking column name here and it'd be more robust to compare record/tablename at the same time, however the data are structured such that this works for a demo.

# %%
cols_not_present = data_columns_needed[~data_columns_needed['name'].isin(cols_present['column_name'])]

# %% [markdown]
# Next eliminate everything that should be present but would be found in a table that's been stored as a JSONB type so isn't in information_schema

# %%
nonjson_cols_not_present= cols_not_present[~cols_not_present['recordname'].isin(json_tables['table_name'])]
nonjson_cols_not_present
# Out:
#       recordname    name  maxlen
# 32        MREC01   mv033       8
# 46        MREC11  md463e       1
# 55        MREC11   mv108       1
# 56        MREC11   mv109       1
# 57        MREC11   mv110       1
# ...          ...     ...     ...
# 50991     RECHVC   hvc60       3
# 50992     RECHVC   hvc61       1
# 50993     RECHVC   hvc62       2
# 50994     RECHVC   hvc68       1
# 50995     RECHVC   idxhv       2
#
# [7293 rows x 3 columns]

# %% [markdown]
# Next eliminate everything that belongs to a table which is entirely missing
#
# These columns all need adding

# %%
cols_missing = nonjson_cols_not_present[~nonjson_cols_not_present['recordname'].isin(data_tables_missing['recordname'])]
#data_cols_missing[data_cols_missing['recordname']=='MREC01']
cols_missing
# Out:
#       recordname     name  maxlen
# 32        MREC01    mv033       8
# 46        MREC11   md463e       1
# 55        MREC11    mv108       1
# 56        MREC11    mv109       1
# 57        MREC11    mv110       1
# ...          ...      ...     ...
# 50738     RECHML  sh129ak       1
# 50739     RECHML  sh129al       1
# 50740     RECHML  sh129am       1
# 50741     RECHML  sh129an       1
# 50742     RECHML  sh129ax       1
#
# [6551 rows x 3 columns]

# %% [markdown]
# Do the same check again direct in an SQL query, joining on all the correct columns for safety

# %%
cols_missing_db = pd.read_sql("""
-- Identify columns described in the metadata that are missing from the data,
-- and need to be added to data tables
WITH 
-- all the columns that exist in the data tables schema
existing_cols AS 
    (
        SELECT table_name, column_name, data_type 
        FROM information_schema.columns 
        WHERE table_schema = 'dhs_data_tables'
    )
-- all the columns that are described in the metadta
, req_cols AS 
(
    SELECT recordname, LOWER(name) AS name, MAX(len) AS maxlen
    FROM dhs_survey_specs.table_specs_blank
    GROUP BY recordname, name
)
-- all the tables described in the metadata which are missing in their entirety
, whole_tables_missing AS 
    (
        SELECT DISTINCT recordname from dhs_survey_specs.table_specs_blank
        WHERE recordname NOT IN (
            SELECT DISTINCT table_name AS recordname 
            FROM information_schema.columns
            WHERE table_schema = 'dhs_data_tables')
    )
-- all the tables which have been stored as JSON type, so don't have all their 
-- described columns present in the tables according to information_schema
, json_tables AS 
    (
        SELECT DISTINCT table_name 
        FROM information_schema.columns WHERE data_type = 'jsonb'
    )

SELECT 
    req_cols.* 
    --, existing_cols.column_name AS test_joined
    --, json_tables.table_name AS json_tbl
    --, whole_tables_missing.recordname AS missing_tbl
FROM req_cols
-- NOT IN type checks seem to never complete whereas left join then check null 
-- is almost instant
LEFT JOIN existing_cols ON
 req_cols.name = existing_cols.column_name --AND req_cols.recordname = existing_cols.table_name 
LEFT JOIN json_tables ON
 req_cols.recordname = json_tables.table_name
LEFT JOIN whole_tables_missing ON
 req_cols.recordname = whole_tables_missing.recordname
WHERE existing_cols.column_name is NULL
AND json_tables.table_name IS null 
AND whole_tables_missing.recordname is null
--AND req_cols.recordname != '*'
ORDER BY recordname, name
""", con=engine)

# %%
cols_missing_db['recordname'].unique()
# Out:
# array(['MREC01', 'MREC11', 'MREC31', 'MREC32', 'MREC51', 'MREC61',
#        'MREC71', 'MREC75', 'MREC83', 'MREC84', 'MREC91', 'MREC92',
#        'REC41', 'REC92', 'RECH4', 'RECH5', 'RECH5S', 'RECH6', 'RECH6CS',
#        'RECH6S', 'RECHMH', 'RECHML'], dtype=object)

# %%
for r,n,l in cols_missing_db.values:
    print(r,n,l)
# Out:
# MREC01 mv033 8
# MREC11 md463e 1
# MREC11 mv108 1
# MREC11 mv109 1
# MREC11 mv110 1
# MREC11 mv111 1
# MREC11 mv112 1
# MREC11 mv148 1
# MREC31 mv304a 1
# MREC32 mrec32_group 32
# MREC32 mv312a 2
# MREC32 mv312b 2
# MREC32 mv312c 2
# MREC32 mv313a 1
# MREC32 mv313b 1
# MREC32 mv313c 1
# MREC32 mv361 1
# MREC32 mv362 1
# MREC32 mv363 2
# MREC32 mv364 1
# MREC32 mv366a 1
# MREC32 mv366b 1
# MREC32 mv367 1
# MREC32 mv375a 2
# MREC32 mv375b 2
# MREC32 mv375c 2
# MREC32 mv376 2
# MREC32 mv376a 1
# MREC32 mv384e 1
# MREC32 mv3b0 1
# MREC92 sm514 2
# MREC92 sm515 2
# MREC92 sm516m 2
# MREC92 sm516y 4
# MREC92 sm517 2
# MREC92 sm517a 1
# MREC92 sm517b 1
# MREC92 sm518 5
# MREC92 sm519 1
# MREC92 sm520 2
# MREC92 sm521 1
# MREC92 sm522 1
# MREC92 sm525m 2
# MREC92 sm525y 4
# MREC92 sm526 1
# MREC92 sm817da 3
# MREC92 sm817db 3
# MREC92 sm918a 1
# MREC92 sm918b 1
# MREC92 sm953a 3
# MREC92 sm953b 3
# MREC92 sm954a 3
# MREC92 sm954b 3
# MREC92 sm956a 3
# MREC92 sm956b 3
# MREC92 sm960a 3
# MREC92 sm960b 3
# MREC92 sm961a 3
# MREC92 sm961b 3
# MREC92 sm962 1
# MREC92 smd931a 1
# MREC92 smd931b 1
# MREC92 smd931c 1
# MREC92 smd931d 1
# MREC92 smidx 2
# REC41 s306d 1
# REC41 s306en 2
# REC41 s306eu 1
# REC41 s306g 1
# REC41 s306h 2
# REC92 s215m 2
# REC92 s605 1
# REC92 s608b 1
# REC92 s608c 1
# RECH4 sb103d 2
# RECH4 sb103m 2
# RECH4 sh20ga 1
# RECH4 sh20gb 1
# RECH4 sh20gc 1
# RECH4 sh20gd 1
# RECH4 sh20ge 1
# RECH4 sh20gf 1
# RECH4 sh20gg 1
# RECH4 sh20gh 1
# RECH4 sh20gi 1
# RECH4 sh20gj 1
# RECH4 sh716c 1
# RECH4 sh816c 1
# RECH5 sha216 1
# RECH5 sha220a 1
# RECH5 shawmos 2
# RECH5S sb112bfw 4
# RECH5S sb112fw 4
# RECH6 shc110 1
# RECH6CS sb107a 1
# RECH6S sb211fw 4
# RECH6S sb218fw 4
# RECH6S sha52ai 1
# RECHMH shb127y 1
# RECHML sh129aa 1
# RECHML sh129ab 1
# RECHML sh129ac 1
# RECHML sh129ad 1
# RECHML sh129ae 1
# RECHML sh129af 1
# RECHML sh129ag 1
# RECHML sh129ah 1
# RECHML sh129ai 1
# RECHML sh129aj 1
# RECHML sh129ak 1
# RECHML sh129al 1
# RECHML sh129am 1
# RECHML sh129an 1
# RECHML sh129ax 1

# %%
cols_missing_db
# Out:
#      recordname     name  maxlen
# 0        MREC01    mv033       8
# 1        MREC11   md463e       1
# 2        MREC11    mv108       1
# 3        MREC11    mv109       1
# 4        MREC11    mv110       1
# ...         ...      ...     ...
# 6546     RECHML  sh129ak       1
# 6547     RECHML  sh129al       1
# 6548     RECHML  sh129am       1
# 6549     RECHML  sh129an       1
# 6550     RECHML  sh129ax       1
#
# [6551 rows x 3 columns]

# %%
for datatable in bobs_excellent_list:
    data_table_cols_present = pd.read_sql(f"""
        SELECT table_name, column_name, data_type 
        FROM information_schema.columns 
        WHERE table_name = '{datatable}'""")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-a2064f5628c9> in <module>
# ----> 1 for datatable in bobs_excellent_list:
#       2     data_table_cols_present = pd.read_sql(f"""
#       3         SELECT table_name, column_name, data_type
#       4         FROM information_schema.columns
#       5         WHERE table_name = '{datatable}'""")
#
# NameError: name 'bobs_excellent_list' is not defined
